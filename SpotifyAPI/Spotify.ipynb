# %%
import sys
import spotipy
import spotipy.util as util
import json
import pandas as pd

# %%
#
scope = "user-library-read"
if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()
token = util.prompt_for_user_token(username,scope,client_id="e80ff3306b0f43f7b115893e02093168",
                                   client_secret="bd5644e705be458c81d1175f037f9eb3",redirect_uri="https://api.spotify.com/v1/browse/categories")

# %%
sp=spotipy.Spotify(auth=token)
sp1=sp.search(q="year:2019",type = "track",limit=10,market="us")
song = []
album = []
pop=[]
artist=[]
for i,t in enumerate (sp1["tracks"]["items"]):
    name_1=(i,t["name"])
    album_1=(t["album"]["name"])
    song.append(name_1[1])
    album.append(album_1)
    pop.append(t["popularity"])
    artist.append(t["artists"][0]["name"])
final = {
    "Name": song,
    "Album":album,
    "Popularity":pop,
    "Artist":artist
}

df = pd.DataFrame(final)
new_df=df.sort_values(["Popularity"],ascending=False)

new_df
# Out:
#                                        Name  \
# 7                                  Memories
# 0                                   Circles
# 1                       HIGHEST IN THE ROOM
# 4                       Lose You To Love Me
# 3                                   ROXANNE
# 5                       everything i wanted
# 6                           hot girl bummer
# 2  Bandit (with YoungBoy Never Broke Again)
# 8                                       BOP
# 9                   223's (feat. 9lokknine)
#
#                                       Album  Popularity          Artist
# 7                                  Memories         100        Maroon 5
# 0                      Hollywood's Bleeding          99     Post Malone
# 1                       HIGHEST IN THE ROOM          98    Travis Scott
# 4                       Lose You To Love Me          98    Selena Gomez
# 3                                   ROXANNE          97  Arizona Zervas
# 5                       everything i wanted          97   Billie Eilish
# 6                           hot girl bummer          97       blackbear
# 2  Bandit (with YoungBoy Never Broke Again)          93      Juice WRLD
# 8                                      KIRK          91          DaBaby
# 9                   223's (feat. 9lokknine)          90       YNW Melly

# %%
playlist_name = []
p_id = []
owners_p=[]

playlists=sp.search(q="Top 50",type = "playlist",limit=50)
for x,y in enumerate(playlists["playlists"]["items"]):
    play_name = (x,y["name"])
    playlist_id = y["uri"]
    owners = (y["owner"]["display_name"])
    #owner_final=owners[]
    if owners == "spotifycharts":
        playlist_name.append(play_name[1])
        p_id.append(playlist_id)
        owners_p.append(owners)

play_final = {
    "Playlist Name":playlist_name,
    "Playlist_ID":p_id,
    "Owners":owners_p
}
playlist_df = pd.DataFrame(play_final)
playlist_df
# Out:
#             Playlist Name                              Playlist_ID  \
# 0           Global Top 50  spotify:playlist:37i9dQZEVXbMDoHDwVN2tF
# 1           Brazil Top 50  spotify:playlist:37i9dQZEVXbMXbN3EUUhlg
# 2            Spain Top 50  spotify:playlist:37i9dQZEVXbNFJfN1Vw8d9
# 3          Germany Top 50  spotify:playlist:37i9dQZEVXbJiZcmkrIHGU
# 4           Mexico Top 50  spotify:playlist:37i9dQZEVXbO3qyFxbkOE1
# 5      Netherlands Top 50  spotify:playlist:37i9dQZEVXbKCF6dqVpDkS
# 6        Australia Top 50  spotify:playlist:37i9dQZEVXbJPcfkRz0wJ0
# 7            Italy Top 50  spotify:playlist:37i9dQZEVXbIQnj7RRhdSX
# 8        Argentina Top 50  spotify:playlist:37i9dQZEVXbMMy2roB9myp
# 17  spotifycharts
# 18  spotifycharts
# 19  spotifycharts
# 20  spotifycharts
# 21  spotifycharts
# 22  spotifycharts
# 23  spotifycharts
# 24  spotifycharts
# 25  spotifycharts
# 26  spotifycharts
# 27  spotifycharts
# 28  spotifycharts
# 29  spotifycharts
# 30  spotifycharts
# 31  spotifycharts
# 32  spotifycharts
# 33  spotifycharts
# 34  spotifycharts
# 35  spotifycharts
# 36  spotifycharts
# 37  spotifycharts
# 38  spotifycharts
# 39  spotifycharts
# 40  spotifycharts
# 41  spotifycharts

# %%
playlist_name_t = []
p_id_t = []
owners_p_t=[]

playlists=sp.search(q="Hong Kong Top 50",type = "playlist",limit=50)
for x,y in enumerate(playlists["playlists"]["items"]):
    play_name = (x,y["name"])
    playlist_id = y["uri"]
    owners = (y["owner"]["display_name"])
    #owner_final=owners[]
    if owners == "spotifycharts":
        playlist_name_t.append(play_name[1])
        p_id_t.append(playlist_id)
        owners_p_t.append(owners)

play_final_t = {
    "Playlist Name":playlist_name_t,
    "Playlist_ID":p_id_t,
    "Owners":owners_p_t
}
playlist_df_t = pd.DataFrame(play_final_t)
playlist_df_t.tail()
# Out:
#         Playlist Name                              Playlist_ID         Owners
# 0    Hong Kong Top 50  spotify:playlist:37i9dQZEVXbLwpL8TjsxOG  spotifycharts
# 1  Hong Kong Viral 50  spotify:playlist:37i9dQZEVXbKXd6qahcpCg  spotifycharts

# %%
final_playists_df = pd.concat([playlist_df,playlist_df_t])
final_playists_df
# Out:
#             Playlist Name                              Playlist_ID  \
# 0           Global Top 50  spotify:playlist:37i9dQZEVXbMDoHDwVN2tF
# 1           Brazil Top 50  spotify:playlist:37i9dQZEVXbMXbN3EUUhlg
# 2            Spain Top 50  spotify:playlist:37i9dQZEVXbNFJfN1Vw8d9
# 3          Germany Top 50  spotify:playlist:37i9dQZEVXbJiZcmkrIHGU
# 4           Mexico Top 50  spotify:playlist:37i9dQZEVXbO3qyFxbkOE1
# 5      Netherlands Top 50  spotify:playlist:37i9dQZEVXbKCF6dqVpDkS
# 6        Australia Top 50  spotify:playlist:37i9dQZEVXbJPcfkRz0wJ0
# 7            Italy Top 50  spotify:playlist:37i9dQZEVXbIQnj7RRhdSX
# 8        Argentina Top 50  spotify:playlist:37i9dQZEVXbMMy2roB9myp
# 9           Sweden Top 50  spotify:playlist:37i9dQZEVXbLoATJ81JYXz
# 10           Japan Top 50  spotify:playlist:37i9dQZEVXbKXQ4mDTEBXq
# 11           Chile Top 50  spotify:playlist:37i9dQZEVXbL0GavIqMTeb
# 12       Indonesia Top 50  spotify:playlist:37i9dQZEVXbObFQZ3JLcXt
# 13          Norway Top 50  spotify:playlist:37i9dQZEVXbJvfa0Yxg7E7
# 14          France Top 50  spotify:playlist:37i9dQZEVXbIPWwFssbupI
# 15     Philippines Top 50  spotify:playlist:37i9dQZEVXbNBz9cRCSFkY
# 16        Colombia Top 50  spotify:playlist:37i9dQZEVXbOa2lmxNORXQ
# 17           India Top 50  spotify:playlist:37i9dQZEVXbLZ52XmnySJg
# 18          Turkey Top 50  spotify:playlist:37i9dQZEVXbIVYVBNw9D5K
# 19   United States Top 50  spotify:playlist:37i9dQZEVXbLRQDuF5jeBp
# 20         Finland Top 50  spotify:playlist:37i9dQZEVXbMxcczTSoGwZ
# 21  United Kingdom Top 50  spotify:playlist:37i9dQZEVXbLnolsZ8PSNw
# 22            Peru Top 50  spotify:playlist:37i9dQZEVXbJfdy5b0KP7W
# 23         Denmark Top 50  spotify:playlist:37i9dQZEVXbL3J0k32lWnN
# 24         Ireland Top 50  spotify:playlist:37i9dQZEVXbKM896FDX8L1
# 25        Paraguay Top 50  spotify:playlist:37i9dQZEVXbNOUPGj7tW6T
# 26          Canada Top 50  spotify:playlist:37i9dQZEVXbKj23U1GF4IR
# 27          Taiwan Top 50  spotify:playlist:37i9dQZEVXbMnZEatlMSiu
# 28          Poland Top 50  spotify:playlist:37i9dQZEVXbN6itCcaL3Tt
# 29         Belgium Top 50  spotify:playlist:37i9dQZEVXbJNSeeHswcKB
# 30        Thailand Top 50  spotify:playlist:37i9dQZEVXbMnz8KIWsvf9
# 31       Singapore Top 50  spotify:playlist:37i9dQZEVXbK4gjvS1FjPY
# 32        Malaysia Top 50  spotify:playlist:37i9dQZEVXbJlfUljuZExa
# 33         Ecuador Top 50  spotify:playlist:37i9dQZEVXbJlM6nvL1nD1
# 34        Portugal Top 50  spotify:playlist:37i9dQZEVXbKyJS56d1pgi
# 35          Panama Top 50  spotify:playlist:37i9dQZEVXbKypXHVwk1f0
# 36         Hungary Top 50  spotify:playlist:37i9dQZEVXbNHwMxAkvmF8
# 37         Uruguay Top 50  spotify:playlist:37i9dQZEVXbMJJi3wgRbAy
# 38       Guatemala Top 50  spotify:playlist:37i9dQZEVXbLy5tBFyQvd4
# 39         Bolivia Top 50  spotify:playlist:37i9dQZEVXbJqfMFK4d691
# 40     Switzerland Top 50  spotify:playlist:37i9dQZEVXbJiyhoAPEfMK
# 41         Vietnam Top 50  spotify:playlist:37i9dQZEVXbLdGSmz6xilI
# 0        Hong Kong Top 50  spotify:playlist:37i9dQZEVXbLwpL8TjsxOG
# 1      Hong Kong Viral 50  spotify:playlist:37i9dQZEVXbKXd6qahcpCg
#
#            Owners
# 0   spotifycharts
# 1   spotifycharts
# 2   spotifycharts
# 3   spotifycharts
# 4   spotifycharts
# 5   spotifycharts
# 6   spotifycharts
# 7   spotifycharts
# 8   spotifycharts
# 9   spotifycharts
# 10  spotifycharts
# 11  spotifycharts
# 12  spotifycharts
# 13  spotifycharts
# 14  spotifycharts
# 15  spotifycharts
# 16  spotifycharts
# 17  spotifycharts
# 18  spotifycharts
# 19  spotifycharts
# 20  spotifycharts
# 21  spotifycharts
# 22  spotifycharts
# 23  spotifycharts
# 24  spotifycharts
# 25  spotifycharts
# 26  spotifycharts
# 27  spotifycharts
# 28  spotifycharts
# 29  spotifycharts
# 30  spotifycharts
# 31  spotifycharts
# 32  spotifycharts
# 33  spotifycharts
# 34  spotifycharts
# 35  spotifycharts
# 36  spotifycharts
# 37  spotifycharts
# 38  spotifycharts
# 39  spotifycharts
# 40  spotifycharts
# 41  spotifycharts
# 0   spotifycharts
# 1   spotifycharts

# %%
import requests
tracks = []
p_id2=[]
test = []
p_name = []
t_ids = []
p_list=final_playists_df["Playlist_ID"]
data=p_list.str.split(":")
for x in data:
    id =(x[2])
    p_id2.append(id)
headers = {"Content-Type":"application/json",
    "Authorization":"Bearer BQCXR-RO6hiJS8xtTmwYf2-NRMDSCzooacO_SgBOyH6Y5JqA_nJJVlV4R7Err-jwKrAZfJ_cK8Y5hOnuwbFtpLLF9C4Y78rplNEEtqcVaWCZFBWGKQnkmTxCePhub5fjzoYjZu_X_do"}
for x in p_id2:
    url =f"https://api.spotify.com/v1/playlists/{x}/tracks"
    response = requests.get(url,headers=headers)
    response_json = response.json()
    response_json["items"]
    rank=1
    cur_play = final_playists_df.loc[final_playists_df["Playlist_ID"] == f"spotify:playlist:{x}"]["Playlist Name"].unique()[0]
    for i,t in enumerate (response_json["items"]):
        name=(t["track"]["name"])
        t_id=(t["track"]["id"])
        tracks.append(name)
        t_ids.append(t_id)
        test.append(x)
        p_name.append(cur_play)
        rank = rank + 1
        if (rank == 6):
            break

# %%
music_df = pd.DataFrame({
    "Playlist Name" : p_name,
    "Playlist ID" : test,
    "Song" : tracks,
    "ID":t_ids
})
music_df["Playlist Name"] = music_df["Playlist Name"].replace({'United States Top 50' : 'US Top 50', 'United Kingdom Top 50' : 'UK Top 50', 'Hong Kong Viral 50': 'HK Viral 50'})
music_df
#music_df.to_csv("data.csv")
# Out:
#      Playlist Name             Playlist ID  \
# 0    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 1    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 2    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 3    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 4    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# ..             ...                     ...
# 215    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 216    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 217    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 218    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 219    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
#
#                                                Song                      ID
# 0                                      Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 1                                           ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 2                                          Memories  2b8fOow8UzyDFAE27YhOZM
# 3                                           Circles  21jGcNKet2qwijlDFuPiPb
# 4                                 Someone You Loved  7qEHsqek33rTcFNT9PFqLf
# ..                                              ...                     ...
# 215                                         Falling  4TnjEaWOeW0eKTKIEvJyCa
# 216                                         ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 217                                   Yellow Hearts  2W4yABdLc4Jnds67Poi5Nl
# 218                   Binalewala - Original Version  2tR5liucorXRwduxr0qEx6
# 219  Into the Unknown - Panic! At The Disco Version  421eObjg0DTm2qajJl5OJm
#
# [220 rows x 4 columns]

# %%
country = []
Range=music_df["Playlist Name"].str.split(" ")[:,]
#Range=music_df["Playlist Name"].str.split("Top 50")

for x in Range:
    n_c=(x[0])
    country.append(n_c)
music_df["Country"]=country
music_df
music_df.to_csv("music.csv")

music_df
# Out:
#      Playlist Name             Playlist ID  \
# 0    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 1    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 2    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 3    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# 4    Global Top 50  37i9dQZEVXbMDoHDwVN2tF
# ..             ...                     ...
# 215    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 216    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 217    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 218    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
# 219    HK Viral 50  37i9dQZEVXbKXd6qahcpCg
#
#                                                Song                      ID  \
# 0                                      Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 1                                           ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 2                                          Memories  2b8fOow8UzyDFAE27YhOZM
# 3                                           Circles  21jGcNKet2qwijlDFuPiPb
# 4                                 Someone You Loved  7qEHsqek33rTcFNT9PFqLf
# ..                                              ...                     ...
# 215                                         Falling  4TnjEaWOeW0eKTKIEvJyCa
# 216                                         ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 217                                   Yellow Hearts  2W4yABdLc4Jnds67Poi5Nl
# 218                   Binalewala - Original Version  2tR5liucorXRwduxr0qEx6
# 219  Into the Unknown - Panic! At The Disco Version  421eObjg0DTm2qajJl5OJm
#
#     Country
# 0    Global
# 1    Global
# 2    Global
# 3    Global
# 4    Global
# ..      ...
# 215      HK
# 216      HK
# 217      HK
# 218      HK
# 219      HK
#
# [220 rows x 5 columns]

# %%
m_country=["Hong","Netherlands","Russia","Australia","Canada","France","Japan","Germany","US", "UK"
]

final_music=music_df.loc[music_df["Country"].isin(m_country)]



music_df.loc[music_df['Country'].isin(m_country)]


final_music
#final_music.to_csv("Final.csv")
# Out:
#           Playlist Name             Playlist ID  \
# 15       Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 16       Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 17       Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 18       Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 19       Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 25   Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 26   Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 27   Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 28   Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 29   Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 30     Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 31     Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 32     Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 33     Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 34     Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 50         Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 51         Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 52         Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 53         Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 54         Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 70        France Top 50  37i9dQZEVXbIPWwFssbupI
# 71        France Top 50  37i9dQZEVXbIPWwFssbupI
# 72        France Top 50  37i9dQZEVXbIPWwFssbupI
# 73        France Top 50  37i9dQZEVXbIPWwFssbupI
# 74        France Top 50  37i9dQZEVXbIPWwFssbupI
# 95            US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 96            US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 97            US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 98            US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 99            US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 105           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 106           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 107           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 108           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 109           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 130       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 131       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 132       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 133       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 134       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 210    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 211    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 212    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 213    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 214    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
#
#                                       Song                      ID  \
# 15                                  Roller  6hw1Sy9wZ8UCxYGdpKrU6M
# 16           Der Bratan bleibt der gleiche  2M39v73rNJmAXUXIW0oagP
# 17                            Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 18            Skifahren (feat. Joshi Mizu)  1E1YyZjbteIz2XQyLvtRxD
# 19               Wieso tust Du dir das an?  6dNB3XdAzx7kTf5wa8Rg89
# 25                            Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 26                            Pa Olvidarte  1RO8Q3w2Jkir8cvvGEApI0
# 27                                Memories  2b8fOow8UzyDFAE27YhOZM
# 28                                 ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 29                     everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ
# 30                            Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 31                                 ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 32                         Don't Start Now  6WrI0LAC5M1Rw2MnX2ZvEg
# 33                                 Circles  21jGcNKet2qwijlDFuPiPb
# 34                                Memories  2b8fOow8UzyDFAE27YhOZM
# 50                               Pretender  58dxGXavrcagRqA58fNB0Z
# 51                               Hakujitsu  0mNO3xUzjsI17GXO1DRFCH
# 52                                      宿命  2yozZfRYHP7Elsymghu5t3
# 53                                  イエスタデイ  3S3DDZrPOYTirleXRyHnNM
# 54                                   ノーダウト  5DMEvbg3gUmiR5HIBWdveV
# 70                          Ne reviens pas  4TnFANpjVwVKWzkxNzIyFH
# 71                                 Popopop  18HNGxDOcshRU2Hdu8tMOM
# 72                            Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 73                    Mayday (feat. Ninho)  1SVuEeerYIwjCRsF5MGzX3
# 74                                  Jamais  2MCAs3ttHSuDm1RHL0rqTF
# 95                                 ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 96                               Heartless  57vxBYXtHMk6H1aD29V7PU
# 97                                 Circles  21jGcNKet2qwijlDFuPiPb
# 98                         Blinding Lights  0sf12qNH5qcw8qpgymFOqD
# 99                     HIGHEST IN THE ROOM  3eekarcy7kvN4yt5ZFzltW
# 105                           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 106        All I Want for Christmas Is You  0bYg9bo50gSsH3LtXe2SQn
# 107                          Before You Go  2gMXnyrvIjhVBUZwvLZDMP
# 108                         Last Christmas  2FRnf9qhLbvw8fu4IBXx78
# 109  Own It (feat. Ed Sheeran & Burna Boy)  07s9NNOT0sZQp7TyolLLgu
# 130                           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 131                              Heartless  57vxBYXtHMk6H1aD29V7PU
# 132                                ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 133                        Blinding Lights  0sf12qNH5qcw8qpgymFOqD
# 134                                Circles  21jGcNKet2qwijlDFuPiPb
# 210                               Señorita  6v3KW9xbzN5yKLt9YKDYA2
# 211                               Memories  2b8fOow8UzyDFAE27YhOZM
# 212                    everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ
# 213                                Circles  21jGcNKet2qwijlDFuPiPb
# 214                                ROXANNE  696DnlkuDOXcMAnKlTgXXK
#
#          Country
# 15       Germany
# 16       Germany
# 17       Germany
# 18       Germany
# 19       Germany
# 25   Netherlands
# 26   Netherlands
# 27   Netherlands
# 28   Netherlands
# 29   Netherlands
# 30     Australia
# 31     Australia
# 32     Australia
# 33     Australia
# 34     Australia
# 50         Japan
# 51         Japan
# 52         Japan
# 53         Japan
# 54         Japan
# 70        France
# 71        France
# 72        France
# 73        France
# 74        France
# 95            US
# 96            US
# 97            US
# 98            US
# 99            US
# 105           UK
# 106           UK
# 107           UK
# 108           UK
# 109           UK
# 130       Canada
# 131       Canada
# 132       Canada
# 133       Canada
# 134       Canada
# 210         Hong
# 211         Hong
# 212         Hong
# 213         Hong
# 214         Hong

# %%
#url="https://api.spotify.com/v1/audio-features/{id}"
headers = {"Content-Type":"application/json",
    "Authorization":"Bearer BQCfLix_zODw3P5Uz6TgIAm3dOnpfo2-rQjMZLG4IAmucrwbOLtQc05pTpvV9j9GmJqwQrbIAV0AEujP1Vo7tMiXI06h5AA70DZXbRpCbqgIBIXZAnOVH_611wZMh_S7ZNV_9ravsGw"}

track_response=requests.get("https://api.spotify.com/v1/audio-features/1rgnBhdG2JDFTbYkYRZAku",headers=headers).json()
track_response
# Out:
# {'danceability': 0.825,
#  'energy': 0.593,
#  'key': 6,
#  'loudness': -6.401,
#  'mode': 0,
#  'speechiness': 0.0988,
#  'acousticness': 0.688,
#  'instrumentalness': 0.000161,
#  'liveness': 0.17,
#  'valence': 0.54,
#  'tempo': 98.078,
#  'type': 'audio_features',
#  'id': '1rgnBhdG2JDFTbYkYRZAku',
#  'uri': 'spotify:track:1rgnBhdG2JDFTbYkYRZAku',
#  'track_href': 'https://api.spotify.com/v1/tracks/1rgnBhdG2JDFTbYkYRZAku',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rgnBhdG2JDFTbYkYRZAku',
#  'duration_ms': 209755,
#  'time_signature': 4}

# %%
track_ids = music_df["ID"]



def t_analysis (track_ids):
    headers = {"Content-Type":"application/json",
    "Authorization":"Bearer BQCfLix_zODw3P5Uz6TgIAm3dOnpfo2-rQjMZLG4IAmucrwbOLtQc05pTpvV9j9GmJqwQrbIAV0AEujP1Vo7tMiXI06h5AA70DZXbRpCbqgIBIXZAnOVH_611wZMh_S7ZNV_9ravsGw"}
    
    danceability = []
    energy = []
    loudness = []
    speechiness = []
    acousticness = []
    instrumentalness = []
    liveness = []
    valence = []
    tempo = []
    
    try:
        for x in track_ids:
            url= f"https://api.spotify.com/v1/audio-features/{x}"
            t_r=requests.get(url,headers=headers).json()
            danceability.append(t_r['danceability'])
            energy.append(t_r["energy"])
            loudness.append(t_r["loudness"])
            speechiness.append(t_r["speechiness"])
            acousticness.append(t_r["acousticness"])
            instrumentalness.append(t_r["instrumentalness"])
            liveness.append(t_r["liveness"])
            valence.append(t_r["valence"])
            tempo.append(t_r["tempo"])
    except KeyError as E:
        pass
    return danceability,energy,loudness,speechiness,acousticness,instrumentalness,liveness,valence,tempo

# %%
a,b,c,d,e,f,g,h,i=t_analysis(track_ids)

# %%
a,b,c,d,e,f,g,h,i
# Out:
# ([0.825,
#   0.621,
#   0.764,
#   0.695,
#   0.501,
#   0.826,
#   0.832,
#   0.722,
#   0.665,
#   0.528,
#   0.803,
#   0.673,
#   0.738,
#   0.886,
#   0.817,
#   0.941,
#   0.612,
#   0.825,
#   0.719,
#   0.856,
#   0.803,
#   0.886,
#   0.754,
#   0.721,
#   0.825,
#   0.825,
#   0.718,
#   0.764,
#   0.621,
#   0.704,
#   0.825,
#   0.621,
#   0.794,
#   0.695,
#   0.764,
#   0.692,
#   0.655,
#   0.748,
#   0.656,
#   0.825,
#   0.721,
#   0.879,
#   0.654,
#   0.658,
#   0.781,
#   0.825,
#   0.786,
#   0.445,
#   0.885,
#   0.335,
#   0.538,
#   0.606,
#   0.547,
#   0.541,
#   0.574,
#   0.803,
#   0.886,
#   0.654,
#   0.879,
#   0.817,
#   0.764,
#   0.508,
#   0.825,
#   0.338,
#   0.435,
#   0.825,
#   0.335,
#   0.735,
#   0.501,
#   0.513,
#   0.932,
#   0.833,
#   0.825,
#   0.614,
#   0.641,
#   0.764,
#   0.669,
#   0.848,
#   0.654,
#   0.501,
#   0.803,
#   0.879,
#   0.721,
#   0.754,
#   0.87,
#   0.695,
#   0.473,
#   0.526,
#   0.764,
#   0.696,
#   0.628,
#   0.801,
#   0.743,
#   0.81],
#  [0.593,
#   0.601,
#   0.32,
#   0.762,
#   0.405,
#   0.73,
#   0.55,
#   0.84,
#   0.743,
#   0.87,
#   0.715,
#   0.752,
#   0.748,
#   0.672,
#   0.665,
#   0.758,
#   0.704,
#   0.593,
#   0.705,
#   0.477,
#   0.715,
#   0.672,
#   0.646,
#   0.716,
#   0.593,
#   0.593,
#   0.86,
#   0.32,
#   0.601,
#   0.225,
#   0.593,
#   0.601,
#   0.793,
#   0.762,
#   0.32,
#   0.792,
#   0.814,
#   0.662,
#   0.661,
#   0.593,
#   0.716,
#   0.703,
#   0.672,
#   0.901,
#   0.866,
#   0.593,
#   0.691,
#   0.643,
#   0.57,
#   0.625,
#   0.869,
#   0.901,
#   0.577,
#   0.8,
#   0.936,
#   0.715,
#   0.672,
#   0.672,
#   0.703,
#   0.665,
#   0.32,
#   0.293,
#   0.593,
#   0.251,
#   0.2,
#   0.593,
#   0.625,
#   0.478,
#   0.405,
#   0.144,
#   0.778,
#   0.652,
#   0.593,
#   0.596,
#   0.673,
#   0.32,
#   0.42,
#   0.447,
#   0.63,
#   0.57,
#   0.715,
#   0.703,
#   0.716,
#   0.646,
#   0.706,
#   0.727,
#   0.401,
#   0.659,
#   0.32,
#   0.704,
#   0.725,
#   0.688,
#   0.68,
#   0.631],
#  [-6.401,
#   -5.616,
#   -7.209,
#   -3.497,
#   -5.679,
#   -3.032,
#   -7.026,
#   -3.24,
#   0.0574,
#   0.0569,
#   0.237,
#   0.108,
#   0.0872,
#   0.533,
#   0.154,
#   0.134,
#   0.0822,
#   0.155,
#   0.0549,
#   0.15,
#   0.183,
#   0.119],
#  [0.54,
#   0.457,
#   0.575,
#   0.553,
#   0.446,
#   0.605,
#   0.881,
#   0.851,
#   0.658,
#   0.714,
#   0.574,
#   0.699,
#   0.896,
#   0.526,
#   0.662,
#   0.683,
#   0.672,
#   0.54,
#   0.435,
#   0.46,
#   0.574,
#   0.526,
#   0.429,
#   0.667,
#   0.54,
#   0.54,
#   0.914,
#   0.575,
#   0.457,
#   0.243,
#   0.54,
#   0.457,
#   0.677,
#   0.553,
#   0.575,
#   0.566,
#   0.69,
#   0.346,
#   0.509,
#   0.54,
#   0.667,
#   0.788,
#   0.343,
#   0.708,
#   0.864,
#   0.54,
#   0.307,
#   0.513,
#   0.86,
#   0.346,
#   0.369,
#   0.748,
#   0.494,
#   0.56,
#   0.793,
#   0.574,
#   0.526,
#   0.343,
#   0.788,
#   0.662,
#   0.575,
#   0.395,
#   0.54,
#   0.0963,
#   0.244,
#   0.54,
#   0.346,
#   0.947,
#   0.446,
#   0.43,
#   0.933,
#   0.414,
#   0.54,
#   0.248,
#   0.785,
#   0.575,
#   0.523,
#   0.353,
#   0.43,
#   0.311,
#   0.574,
#   0.788,
#   0.667,
#   0.429,
#   0.593,
#   0.864,
#   0.345,
#   0.586,
#   0.575,
#   0.426,
#   0.458,
#   0.41,
#   0.694,
#   0.407],
#  [98.078,
#   116.735,
#   91.019,
#   120.042,
#   109.891,
#   150.134,
#   154.064,
#   150.108,
#   131.573,
#   152.37,
#   101.085,
#   178.005,
#   94.949,
#   91.976,
#   104.957,
#   128.02,
#   96.015,
#   98.078,
#   133.927,
#   133.962,
#   101.085,
#   91.976,
#   176.089,
#   104.994,
#   98.078,
#   98.078,
#   89.97,
#   91.019,
#   116.735,
#   120.006,
#   98.078,
#   116.735,
#   123.941,
#   120.042,
#   91.019,
#   129.883,
#   180.082,
#   157.918,
#   140.956,
#   98.078,
#   104.994,
#   94.004,
#   181.857,
#   93.979,
#   95.993,
#   98.078,
#   129.768,
#   88.204,
#   105.036,
#   150.277,
#   91.972,
#   93.012,
#   164.032,
#   129.939,
#   149.953,
#   101.085,
#   91.976,
#   181.857,
#   94.004,
#   104.957,
#   91.019,
#   91.511,
#   98.078,
#   116.419,
#   136.054,
#   98.078,
#   150.277,
#   107.682,
#   109.891,
#   134.037,
#   124.996,
#   130.002,
#   98.078,
#   152.138,
#   149.974,
#   91.019,
#   95.049,
#   117.959,
#   89.991,
#   139.516,
#   101.085,
#   94.004,
#   104.994,
#   176.089,
#   100.013,
#   118.034,
#   90.076,
#   79.907,
#   91.019,
#   124.972,
#   173.952,
#   158.003,
#   180.059,
#   144.978])

# %%
dict_1 = {
    "Dance": a
    
}
pd.DataFrame(dict_1)
# Out:
#     Dance
# 0   0.825
# 1   0.621
# 2   0.764
# 3   0.695
# 4   0.501
# ..    ...
# 89  0.696
# 90  0.628
# 91  0.801
# 92  0.743
# 93  0.810
#
# [94 rows x 1 columns]
