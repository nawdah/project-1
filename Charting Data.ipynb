# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
merge_df = pd.read_csv('Resources/track_analysis.csv')
merge_df
# Out:
#      Unnamed: 0    Country                                      Name  \
# 0             0  Australia                              Dance Monkey
# 1             1  Australia                           Don't Start Now
# 2             2  Australia                              Lucid Dreams
# 3             3  Australia                                   Ride It
# 4             4  Australia                       Never Seen the Rain
# ..          ...        ...                                       ...
# 130         130         US                              Lucid Dreams
# 131         131         US  Bandit (with YoungBoy Never Broke Again)
# 132         132         US                                   ROXANNE
# 133         133         US                                   Circles
# 134         134         US                                   Robbery
#
#              Artist                     Album        Genre  Rank   Source  \
# 0       Tones and I     Dance Monkey - Single          Pop     1    Apple
# 1          Dua Lipa  Don't Start Now - Single          Pop     2    Apple
# 2        Juice WRLD   Goodbye & Good Riddance  Hip-Hop/Rap     3    Apple
# 3            Regard          Ride It - Single        Dance     4    Apple
# 4       Tones and I  The Kids Are Coming - EP  Alternative     5    Apple
# ..              ...                       ...          ...   ...      ...
# 130      Juice WRLD   Goodbye & Good Riddance  Hip-Hop/Rap     1  Spotify
# 131             NaN                       NaN          NaN     2  Spotify
# 132  Arizona Zervas          ROXANNE - Single  Hip-Hop/Rap     3  Spotify
# 133     Post Malone      Hollywood's Bleeding  Hip-Hop/Rap     4  Spotify
# 134      Juice WRLD       Death Race for Love  Hip-Hop/Rap     5  Spotify
#
#                  Spotify ID  danceability  energy  key  loudness  speechiness  \
# 0    2XU0oxnq2qxCpomAAuJY8K         0.824   0.588    6    -6.400       0.0924
# 1    6WrI0LAC5M1Rw2MnX2ZvEg         0.794   0.793   11    -4.521       0.0842
# 2    285pBltuF7vW8TeWk8hdRR         0.511   0.566    6    -7.230       0.2000
# 3    2tnVG71enUj33Ic2nFN6kZ         0.882   0.780    0    -4.256       0.0939
# 4    0JQ5MbyriK6ruD3t6RZ7ix         0.672   0.464    6    -5.624       0.0370
# ..                      ...           ...     ...  ...       ...          ...
# 130  285pBltuF7vW8TeWk8hdRR         0.511   0.566    6    -7.230       0.2000
# 131  6Gg1gjgKi2AK4e0qzsR7sd         0.474   0.631    5    -5.884       0.3430
# 132  696DnlkuDOXcMAnKlTgXXK         0.621   0.601    6    -5.616       0.1480
# 133  21jGcNKet2qwijlDFuPiPb         0.695   0.762    0    -3.497       0.0395
# 134  6Hj9jySrnFppAI0sEMCZpJ         0.685   0.692    2    -5.122       0.0457
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.6920          0.000104    0.1490    0.513   98.027       209438
# 1          0.0125          0.000000    0.0952    0.677  123.941       183290
# 2          0.3490          0.000000    0.3400    0.218   83.903       239836
# 3          0.1590          0.000052    0.0973    0.867  117.945       157606
# 4          0.4300          0.000000    0.2840    0.271   92.069       200742
# ..            ...               ...       ...      ...      ...          ...
# 130        0.3490          0.000000    0.3400    0.218   83.903       239836
# 131        0.0687          0.000000    0.1320    0.425  180.051       189323
# 132        0.0522          0.000000    0.4600    0.457  116.735       163636
# 133        0.1920          0.002440    0.0863    0.553  120.042       215280
# 134        0.3280          0.000000    0.1530    0.578  159.966       240051
#
# [135 rows x 20 columns]

# %%
country_df = merge_df.groupby(["Country"])
mean_value = country_df.mean()
country_mean = mean_value.reset_index()

country_mean
# Out:
#        Country  Unnamed: 0  Rank  danceability    energy       key  loudness  \
# 0    Australia         7.0   3.0      0.679533  0.621267  6.600000 -6.568533
# 1       Canada        22.0   3.0      0.608867  0.609867  5.866667 -6.737667
# 2       France        37.0   3.0      0.727267  0.631733  6.800000 -6.809133
# 3      Germany        52.0   3.0      0.706867  0.579333  6.466667 -7.057933
# 4    Hong Kong        67.0   3.0      0.614067  0.490267  7.866667 -8.227400
# 5        Japan        82.0   3.0      0.491600  0.622800  6.200000 -7.746467
# 6  Netherlands        97.0   3.0      0.626400  0.565600  6.866667 -7.648000
# 7           UK       112.0   3.0      0.632400  0.624467  7.266667 -6.767600
# 8           US       127.0   3.0      0.635133  0.589867  5.666667 -7.138733
#
#    speechiness  acousticness  instrumentalness  liveness   valence  \
# 0     0.118653      0.290201          0.052652  0.172333  0.466000
# 1     0.158493      0.262006          0.052662  0.188740  0.410000
# 2     0.156167      0.331135          0.052496  0.129360  0.482467
# 3     0.195947      0.289881          0.052503  0.194867  0.441867
# 4     0.078940      0.458055          0.096484  0.100307  0.437067
# 5     0.078307      0.369661          0.196475  0.148313  0.368600
# 6     0.124367      0.366373          0.096300  0.167920  0.420667
# 7     0.094747      0.308272          0.052486  0.111187  0.424400
# 8     0.175620      0.202761          0.052657  0.207793  0.418933
#
#         tempo    duration_ms
# 0  117.189267  204425.533333
# 1  129.853133  205687.333333
# 2  124.901200  210404.533333
# 3  126.517067  231878.600000
# 4  128.187867  213594.333333
# 5  124.366133  231431.200000
# 6  125.882067  217345.666667
# 7  123.898200  218610.600000
# 8  135.530333  203360.333333

# %%
x_axis = np.arange(len(country_mean))
tick_locations = [value for value in x_axis]
fig,ax=plt.subplots(figsize=(50,20))

bar_1=ax.bar(x_axis+0.10, country_mean["danceability"], label="danceability", color='r', width=0.10)
bar_2=ax.bar(x_axis+0.20, country_mean["energy"],label="energy", color='g', width=0.10)
bar_3=ax.bar(x_axis+0.30, country_mean["speechiness"], label="speechiness",color='b', width=0.10)
bar_4=ax.bar(x_axis+0.40, country_mean["acousticness"], label="acousticness", color='y', width=0.10)
bar_5=ax.bar(x_axis+0.50, country_mean["instrumentalness"], label="instrumentalness",color='purple', width=0.10)
bar_6=ax.bar(x_axis+0.60, country_mean["liveness"],label="liveness", color='c', width=0.10)
bar_7=ax.bar(x_axis+0.70, country_mean["valence"],label="valence",  color='darkorange', width=0.10)

plt.legend()
plt.grid()

def autolabel(rects):
    for p in rects:
        height = '{:.2f}%'.format(p.get_height()*100)
        x = p.get_x() + p.get_width()/2-.05
        y = p.get_y() + p.get_height()+.01
        ax.annotate(height, (x, y), color='k')

autolabel(bar_1)
autolabel(bar_2)
autolabel(bar_3)
autolabel(bar_4)
autolabel(bar_5)
autolabel(bar_6)
autolabel(bar_7)


plt.xticks(tick_locations, country_mean["Country"], rotation="vertical")
plt.savefig("avg_feature_country.png")

# %%
country_id = []
for index, row in merge_df.iterrows():
    try:
        if (row["Country"] == "Australia"):
            country_id.append(0)
        elif (row["Country"] == "Canada"):
            country_id.append(1)
        elif (row["Country"] == "Denmark"):
            country_id.append(2)
        elif (row["Country"] == "France"):
            country_id.append(3)
        elif (row["Country"] == "Germany"):
            country_id.append(4)
        elif (row["Country"] == "Hong Kong"):
            country_id.append(5)
        elif (row["Country"] == "Japan"):
            country_id.append(6)
        elif (row["Country"] == "Netherlands"):
            country_id.append(7)
        elif (row["Country"] == "Russia"):
            country_id.append(8)
        elif (row["Country"] == "UK"):
            country_id.append(9)
        elif (row["Country"] == "US"):
            country_id.append(10)
        else:
            country_id.append(100)
            
    except:
        country_id.append(100)

# %%
dance_df = merge_df
dance_df["Country_ID"] = country_id
ax = dance_df.plot(kind='scatter', x='Country_ID', y='danceability')
