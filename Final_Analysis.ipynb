# %%
#importing the neccessary libraries we will need to run our data and analysis

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import sys
import csv

from googletrans import Translator 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import json
from pprint import pprint 

import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

from config import lastfm_api_key
from config import CLIENT_ID, CLIENT_SECRET

# %%
#list of countries we narrow down to sort through our data

countries = ['hk', 'nl', 'au', 'ca', 'fr', 'jp', 'gb', 'de', 'us' ]

# %%
#create a dataframe that takes in all the top 5 songs from each country on our list

song_list = []
artist_list = []
album_list = []
country_list = []
genre_list = []
rank = []

for country in countries:
    top_list = []
    music_url = f"https://rss.itunes.apple.com/api/v1/{country}/apple-music/top-songs/all/5/explicit.json"
    
    try:
        response = requests.get(music_url).json()
        top_list.append(response["feed"]["results"])
        country_df = pd.DataFrame(top_list)
        for x in range (0,5):
            rank.append(x+1)
            song_list.append(country_df[x][0]['name'])
            country_list.append(country)
            artist_list.append(country_df[x][0]['artistName'])
            album_list.append(country_df[x][0]["collectionName"])
            genre_list.append(country_df[x][0]["genres"][0]["name"])
        
    except:
        print(f"Can't find {country}. Skipping... ")
apple_top_df = pd.DataFrame({
    "Country" : country_list,
    "Name" : song_list,
    "Artist" : artist_list,
    "Album" : album_list,
    "Genre" : genre_list,
    "Rank" : rank
})

apple_top_df['Country'] = apple_top_df['Country'].replace({'hk': 'Hong Kong',
                           'nl': 'Netherlands',
                           'au': 'Australia',
                           'ca': 'Canada',
                           'fr': 'France',
                           'jp': 'Japan',
                           'gb': 'UK',
                           'de': 'Germany',
                           'us': 'US'
                          })
apple_top_df['Source'] = 'Apple'
apple_top_df.head()
# Out:
#      Country                 Name                           Artist  \
# 0  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1  Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2  Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3  Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4  Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
#
#                                                Album  Genre  Rank Source
# 0                                  Señorita - Single    流行樂     1  Apple
# 1  Frozen 2 (Original Motion Picture Soundtrack /...    原聲帶     2  Apple
# 2                                      說好不哭 - Single  國語流行樂     3  Apple
# 3  Frozen 2 (Original Motion Picture Soundtrack /...    原聲帶     4  Apple
# 4                       讓愛高飛 (劇集《多功能老婆》片尾曲) - Single    廣東歌     5  Apple

# %%
#cleaning the dataframe to be more readable 

translator = Translator()

apple_top_df['Genre'] = apple_top_df['Genre'].apply(translator.translate, dest='en').apply(getattr, args=('text',))
apple_top_df['Genre'] = apple_top_df['Genre'].replace({'pop music' : 'Pop', 
                                                                   'Mandarin pop music' : 'Pop',
                                                                   'Alternative Music' : 'Alternative',
                                                                   'R & B, soul' : 'R&B/Soul',
                                                                   'priest' : 'Priest'
                                                                })
apple_top_df
# Out:
#         Country                                    Name  \
# 0     Hong Kong                                Señorita
# 1     Hong Kong                        Into the Unknown
# 2     Hong Kong                                    說好不哭
# 3     Hong Kong                           Show Yourself
# 4     Hong Kong                     讓愛高飛 (劇集《多功能老婆》片尾曲)
# 5   Netherlands                            Dance Monkey
# 6   Netherlands                            Lucid Dreams
# 7   Netherlands                     everything i wanted
# 8   Netherlands                         Blinding Lights
# 9   Netherlands         All I Want For Christmas Is You
# 10    Australia                            Dance Monkey
# 11    Australia                         Don't Start Now
# 12    Australia                            Lucid Dreams
# 13    Australia                                 Ride It
# 14    Australia                     Never Seen the Rain
# 15       Canada                            Lucid Dreams
# 16       Canada                                  Bandit
# 17       Canada                            Dance Monkey
# 18       Canada                                 ROXANNE
# 19       Canada                         Blinding Lights
# 20       France  Ne reviens pas (feat. Heuss L'enfoiré)
# 21       France                    Mayday (feat. Ninho)
# 22       France                                     40%
# 23       France                            Dance Monkey
# 24       France                        Mon bébé d'amour
# 25        Japan                               Pretender
# 26        Japan                                      白日
# 27        Japan                                      宿命
# 28        Japan                                  イエスタデイ
# 29        Japan                                 マリーゴールド
# 30           UK   Own It (feat. Ed Sheeran & Burna Boy)
# 31           UK                            Dance Monkey
# 32           UK                           Before You Go
# 33           UK         All I Want For Christmas Is You
# 34           UK                         Don't Start Now
# 35      Germany                             KEIN SCHLAF
# 36      Germany                                    COLT
# 37      Germany           Der Bratan bleibt der gleiche
# 38      Germany                                  Roller
# 39      Germany                            Dance Monkey
# 40           US                            Lucid Dreams
# 41           US                                 The Box
# 42           US                                  Bandit
# 43           US              Start wit Me (feat. Gunna)
# 44           US                  All Girls Are the Same
#
#                                      Artist  \
# 0             Shawn Mendes & Camila Cabello
# 1                     Idina Menzel & AURORA
# 2                                  周杰倫 & 阿信
# 3           Idina Menzel & Evan Rachel Wood
# 4                                       周柏豪
# 5                               Tones and I
# 6                                Juice WRLD
# 7                             Billie Eilish
# 8                                The Weeknd
# 9                              Mariah Carey
# 10                              Tones and I
# 11                                 Dua Lipa
# 12                               Juice WRLD
# 13                                   Regard
# 14                              Tones and I
# 15                               Juice WRLD
# 16  Juice WRLD & YoungBoy Never Broke Again
# 17                              Tones and I
# 18                           Arizona Zervas
# 19                               The Weeknd
# 20                                   Gradur
# 21                                      SCH
# 22                             Aya Nakamura
# 23                              Tones and I
# 24                                      Jul
# 25                           Official髭男dism
# 26                                 King Gnu
# 27                           Official髭男dism
# 28                           Official髭男dism
# 29                                    あいみょん
# 30                                  Stormzy
# 31                              Tones and I
# 32                            Lewis Capaldi
# 33                             Mariah Carey
# 34                                 Dua Lipa
# 35                              Nimo & Hava
# 36                                    Samra
# 37                              Capital Bra
# 38                               Apache 207
# 39                              Tones and I
# 40                               Juice WRLD
# 41                              Roddy Ricch
# 42  Juice WRLD & YoungBoy Never Broke Again
# 43                              Roddy Ricch
# 44                               Juice WRLD
#
#                                                 Album           Genre  Rank  \
# 0                                   Señorita - Single             Pop     1
# 1   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                       說好不哭 - Single             Pop     3
# 3   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                        讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
# 5                               Dance Monkey - Single     Alternative     1
# 6                             Goodbye & Good Riddance    Hiphop / Rap     2
# 7                        everything i wanted - Single     Alternative     3
# 8                            Blinding Lights - Single        R&B/Soul     4
# 9                                     Merry Christmas        Holidays     5
# 10                              Dance Monkey - Single             Pop     1
# 11                           Don't Start Now - Single             Pop     2
# 12                            Goodbye & Good Riddance     Hip-Hop/Rap     3
# 13                                   Ride It - Single           Dance     4
# 14                           The Kids Are Coming - EP     Alternative     5
# 15                            Goodbye & Good Riddance     Hip-Hop/Rap     1
# 16                                    Bandit - Single     Hip-Hop/Rap     2
# 17                              Dance Monkey - Single     Alternative     3
# 18                                   ROXANNE - Single     Hip-Hop/Rap     4
# 19                           Blinding Lights - Single        R&B/Soul     5
# 20                                            Zone 59     Hip-hop/Rap     1
# 21                                            Rooftop     Hip-hop/Rap     2
# 22                          NAKAMURA (Deluxe Edition)        R&B/Soul     3
# 23                           The Kids Are Coming - EP     Alternative     4
# 24                                  C'est pas des LOL     Hip-hop/Rap     5
# 25                                 Pretender - Single           J-Pop     1
# 26                                        白日 - Single     Alternative     2
# 27                                        宿命 - Single           J-Pop     3
# 28                                           Traveler           J-Pop     4
# 29                                         瞬間的シックスセンス           J-Pop     5
# 30                                  Heavy Is The Head     Hip-Hop/Rap     1
# 31                              Dance Monkey - Single     Alternative     2
# 32  Divinely Uninspired To a Hellish Extent (Exten...     Alternative     3
# 33                                    Merry Christmas       Christmas     4
# 34                           Don't Start Now - Single             Pop     5
# 35                                        NIMORIGINAL     Hip-Hop/Rap     1
# 36                                      COLT - Single     Hip-Hop/Rap     2
# 37             Der Bratan bleibt der gleiche - Single     Hip-Hop/Rap     3
# 38                                             Platte     Hip-Hop/Rap     4
# 39                              Dance Monkey - Single     Alternative     5
# 40                            Goodbye & Good Riddance     Hip-Hop/Rap     1
# 41              Please Excuse Me For Being Antisocial     Hip-Hop/Rap     2
# 42                                    Bandit - Single     Hip-Hop/Rap     3
# 43              Please Excuse Me For Being Antisocial     Hip-Hop/Rap     4
# 44                            Goodbye & Good Riddance     Hip-Hop/Rap     5
#
#    Source
# 0   Apple
# 1   Apple
# 2   Apple
# 3   Apple
# 4   Apple
# 5   Apple
# 6   Apple
# 7   Apple
# 8   Apple
# 9   Apple
# 10  Apple
# 11  Apple
# 12  Apple
# 13  Apple
# 14  Apple
# 15  Apple
# 16  Apple
# 17  Apple
# 18  Apple
# 19  Apple
# 20  Apple
# 21  Apple
# 22  Apple
# 23  Apple
# 24  Apple
# 25  Apple
# 26  Apple
# 27  Apple
# 28  Apple
# 29  Apple
# 30  Apple
# 31  Apple
# 32  Apple
# 33  Apple
# 34  Apple
# 35  Apple
# 36  Apple
# 37  Apple
# 38  Apple
# 39  Apple
# 40  Apple
# 41  Apple
# 42  Apple
# 43  Apple
# 44  Apple

# %%
#start of lastFM data search

jsonFormat = '&format=json'

url = 'http://ws.audioscrobbler.com/2.0/?method=chart.gettoptracks'
url_end = '&api_key=' + lastfm_api_key + jsonFormat

# %%
limit = '5'
countries = ["Hong Kong", "Netherlands", "Australia", 
             "Canada", "France", "Japan", "united kingdom", "Germany", "united states"]
song_list = []
artist_list = []
country_list = []
rank = []

for country in countries:
    top_list = []
    urlgeo = 'http://ws.audioscrobbler.com/2.0/?method=geo.gettoptracks&limit=' + limit + '&country=' + country + url_end
    try:
        lastfm_response = requests.get(urlgeo).json()
        top_list.append(lastfm_response["tracks"]["track"])
        temp_df = pd.DataFrame(top_list)
        for x in range (0,5):
            rank.append(x+1)
            song_list.append(temp_df[x][0]['name'])
            country_list.append(country)
            artist_list.append(temp_df[x][0]['artist']['name'])
    except:
        print(f"Couldn't find {country}")

# %%
lastfm_top_df=pd.DataFrame({
    "Country" : country_list,
    "Artist" : artist_list,
    "Name" : song_list,
    "Rank" : rank
})

lastfm_top_df["Source"] = "LastFM"

lastfm_top_df.head()
# Out:
#      Country      Artist                Name  Rank  Source
# 0  Hong Kong       Adele               Hello     1  LastFM
# 1  Hong Kong  The Weeknd  Can't Feel My Face     2  LastFM
# 2  Hong Kong  Ed Sheeran          Photograph     3  LastFM
# 3  Hong Kong  Ed Sheeran   Thinking Out Loud     4  LastFM
# 4  Hong Kong  Ed Sheeran        Shape of You     5  LastFM

# %%
albums = []
for index, row in lastfm_top_df.iterrows():
    track_url = f"http://ws.audioscrobbler.com/2.0/?method=track.getInfo&artist={row['Artist']}&track={row['Name']}&autocorrect=1" + url_end
    lastfm_response = requests.get(track_url).json()
    albums.append(lastfm_response['track']['album']['title'])

# %%
lastfm_response['track']['album']['title']
# Out:
# '25'

# %%
lastfm_top_df["Album"] = albums

# %%
lastfm_top_df.replace(to_replace="united kingdom", value="UK", inplace=True)
lastfm_top_df.replace(to_replace="united states", value="US", inplace=True)

# %%
#start of spotify data search

spotify = spotipy.Spotify()
credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

# %%
spotify =spotipy.Spotify(auth=token)
sp1=spotify.search(q="year:2019",type = "track",limit=10,market="us")\

song = []
album = []
pop=[]
artist=[]
for i,t in enumerate (sp1["tracks"]["items"]):
    name_1=(i,t["name"])
    album_1=(t["album"]["name"])
    song.append(name_1[1])
    album.append(album_1)
    pop.append(t["popularity"])
    artist.append(t["artists"][0]["name"])
final = {
    "Name": song,
    "Album":album,
    "Popularity":pop,
    "Artist":artist
}

df = pd.DataFrame(final)
new_df=df.sort_values(["Popularity"],ascending=False)

new_df
# Out:
#                                        Name  \
# 8                                  Memories
# 0                                   Circles
# 1                       HIGHEST IN THE ROOM
# 4                       everything i wanted
# 5                       Lose You To Love Me
# 2                                   ROXANNE
# 6                           hot girl bummer
# 3  Bandit (with YoungBoy Never Broke Again)
# 7                                       BOP
# 9                   223's (feat. 9lokknine)
#
#                                       Album  Popularity          Artist
# 8                                  Memories         100        Maroon 5
# 0                      Hollywood's Bleeding          99     Post Malone
# 1                       HIGHEST IN THE ROOM          98    Travis Scott
# 4                       everything i wanted          98   Billie Eilish
# 5                       Lose You To Love Me          98    Selena Gomez
# 2                                   ROXANNE          97  Arizona Zervas
# 6                           hot girl bummer          96       blackbear
# 3  Bandit (with YoungBoy Never Broke Again)          93      Juice WRLD
# 7                                      KIRK          91          DaBaby
# 9                   223's (feat. 9lokknine)          90       YNW Melly

# %%
playlist_name = []
p_id = []
owners_p=[]

playlists=spotify.search(q="Top 50",type = "playlist",limit=50)
for x,y in enumerate(playlists["playlists"]["items"]):
    play_name = (x,y["name"])
    playlist_id = y["uri"]
    owners = (y["owner"]["display_name"])
    #owner_final=owners[]
    if owners == "spotifycharts":
        playlist_name.append(play_name[1])
        p_id.append(playlist_id)
        owners_p.append(owners)

play_final = {
    "Playlist Name":playlist_name,
    "Playlist_ID":p_id,
    "Owners":owners_p
}
playlist_df = pd.DataFrame(play_final)
playlist_df
# Out:
#             Playlist Name                              Playlist_ID  \
# 0           Global Top 50  spotify:playlist:37i9dQZEVXbMDoHDwVN2tF
# 1           Brazil Top 50  spotify:playlist:37i9dQZEVXbMXbN3EUUhlg
# 2            Spain Top 50  spotify:playlist:37i9dQZEVXbNFJfN1Vw8d9
# 3          Germany Top 50  spotify:playlist:37i9dQZEVXbJiZcmkrIHGU
# 4           Mexico Top 50  spotify:playlist:37i9dQZEVXbO3qyFxbkOE1
# 5      Netherlands Top 50  spotify:playlist:37i9dQZEVXbKCF6dqVpDkS
# 6        Argentina Top 50  spotify:playlist:37i9dQZEVXbMMy2roB9myp
# 7        Australia Top 50  spotify:playlist:37i9dQZEVXbJPcfkRz0wJ0
# 8            Italy Top 50  spotify:playlist:37i9dQZEVXbIQnj7RRhdSX
# 9            Japan Top 50  spotify:playlist:37i9dQZEVXbKXQ4mDTEBXq
# 10          Sweden Top 50  spotify:playlist:37i9dQZEVXbLoATJ81JYXz
# 11           Chile Top 50  spotify:playlist:37i9dQZEVXbL0GavIqMTeb
# 12       Indonesia Top 50  spotify:playlist:37i9dQZEVXbObFQZ3JLcXt
# 13          France Top 50  spotify:playlist:37i9dQZEVXbIPWwFssbupI
# 14     Philippines Top 50  spotify:playlist:37i9dQZEVXbNBz9cRCSFkY
# 15          Norway Top 50  spotify:playlist:37i9dQZEVXbJvfa0Yxg7E7
# 16           India Top 50  spotify:playlist:37i9dQZEVXbLZ52XmnySJg
# 17        Colombia Top 50  spotify:playlist:37i9dQZEVXbOa2lmxNORXQ
# 18          Turkey Top 50  spotify:playlist:37i9dQZEVXbIVYVBNw9D5K
# 19   United States Top 50  spotify:playlist:37i9dQZEVXbLRQDuF5jeBp
# 20            Peru Top 50  spotify:playlist:37i9dQZEVXbJfdy5b0KP7W
# 21  United Kingdom Top 50  spotify:playlist:37i9dQZEVXbLnolsZ8PSNw
# 22         Finland Top 50  spotify:playlist:37i9dQZEVXbMxcczTSoGwZ
# 23         Ireland Top 50  spotify:playlist:37i9dQZEVXbKM896FDX8L1
# 24         Denmark Top 50  spotify:playlist:37i9dQZEVXbL3J0k32lWnN
# 25        Paraguay Top 50  spotify:playlist:37i9dQZEVXbNOUPGj7tW6T
# 26          Canada Top 50  spotify:playlist:37i9dQZEVXbKj23U1GF4IR
# 27          Taiwan Top 50  spotify:playlist:37i9dQZEVXbMnZEatlMSiu
# 28          Poland Top 50  spotify:playlist:37i9dQZEVXbN6itCcaL3Tt
# 29         Belgium Top 50  spotify:playlist:37i9dQZEVXbJNSeeHswcKB
# 30        Thailand Top 50  spotify:playlist:37i9dQZEVXbMnz8KIWsvf9
# 31       Singapore Top 50  spotify:playlist:37i9dQZEVXbK4gjvS1FjPY
# 32        Malaysia Top 50  spotify:playlist:37i9dQZEVXbJlfUljuZExa
# 33         Ecuador Top 50  spotify:playlist:37i9dQZEVXbJlM6nvL1nD1
# 34        Portugal Top 50  spotify:playlist:37i9dQZEVXbKyJS56d1pgi
# 35          Panama Top 50  spotify:playlist:37i9dQZEVXbKypXHVwk1f0
# 36         Uruguay Top 50  spotify:playlist:37i9dQZEVXbMJJi3wgRbAy
# 37       Guatemala Top 50  spotify:playlist:37i9dQZEVXbLy5tBFyQvd4
# 38         Hungary Top 50  spotify:playlist:37i9dQZEVXbNHwMxAkvmF8
# 39         Bolivia Top 50  spotify:playlist:37i9dQZEVXbJqfMFK4d691
# 40         Vietnam Top 50  spotify:playlist:37i9dQZEVXbLdGSmz6xilI
#
#            Owners
# 0   spotifycharts
# 1   spotifycharts
# 2   spotifycharts
# 3   spotifycharts
# 4   spotifycharts
# 5   spotifycharts
# 6   spotifycharts
# 7   spotifycharts
# 8   spotifycharts
# 9   spotifycharts
# 10  spotifycharts
# 11  spotifycharts
# 12  spotifycharts
# 13  spotifycharts
# 14  spotifycharts
# 15  spotifycharts
# 16  spotifycharts
# 17  spotifycharts
# 18  spotifycharts
# 19  spotifycharts
# 20  spotifycharts
# 21  spotifycharts
# 22  spotifycharts
# 23  spotifycharts
# 24  spotifycharts
# 25  spotifycharts
# 26  spotifycharts
# 27  spotifycharts
# 28  spotifycharts
# 29  spotifycharts
# 30  spotifycharts
# 31  spotifycharts
# 32  spotifycharts
# 33  spotifycharts
# 34  spotifycharts
# 35  spotifycharts
# 36  spotifycharts
# 37  spotifycharts
# 38  spotifycharts
# 39  spotifycharts
# 40  spotifycharts

# %%
playlist_name_t = []
p_id_t = []
owners_p_t=[]

playlists=spotify.search(q="Hong Kong Top 50",type = "playlist",limit=50)
for x,y in enumerate(playlists["playlists"]["items"]):
    play_name = (x,y["name"])
    playlist_id = y["uri"]
    owners = (y["owner"]["display_name"])
    #owner_final=owners[]
    if owners == "spotifycharts":
        playlist_name_t.append(play_name[1])
        p_id_t.append(playlist_id)
        owners_p_t.append(owners)

play_final_t = {
    "Playlist Name":playlist_name_t,
    "Playlist_ID":p_id_t,
    "Owners":owners_p_t
}
playlist_df_t = pd.DataFrame(play_final_t)
playlist_df_t.tail()
# Out:
#         Playlist Name                              Playlist_ID         Owners
# 0    Hong Kong Top 50  spotify:playlist:37i9dQZEVXbLwpL8TjsxOG  spotifycharts
# 1  Hong Kong Viral 50  spotify:playlist:37i9dQZEVXbKXd6qahcpCg  spotifycharts

# %%
final_playists_df = pd.concat([playlist_df,playlist_df_t])
final_playists_df.reset_index(inplace=True, drop=True)
final_playists_df
# Out:
#             Playlist Name                              Playlist_ID  \
# 0           Global Top 50  spotify:playlist:37i9dQZEVXbMDoHDwVN2tF
# 1           Brazil Top 50  spotify:playlist:37i9dQZEVXbMXbN3EUUhlg
# 2            Spain Top 50  spotify:playlist:37i9dQZEVXbNFJfN1Vw8d9
# 3          Germany Top 50  spotify:playlist:37i9dQZEVXbJiZcmkrIHGU
# 4           Mexico Top 50  spotify:playlist:37i9dQZEVXbO3qyFxbkOE1
# 5      Netherlands Top 50  spotify:playlist:37i9dQZEVXbKCF6dqVpDkS
# 6        Argentina Top 50  spotify:playlist:37i9dQZEVXbMMy2roB9myp
# 7        Australia Top 50  spotify:playlist:37i9dQZEVXbJPcfkRz0wJ0
# 8            Italy Top 50  spotify:playlist:37i9dQZEVXbIQnj7RRhdSX
# 9            Japan Top 50  spotify:playlist:37i9dQZEVXbKXQ4mDTEBXq
# 10          Sweden Top 50  spotify:playlist:37i9dQZEVXbLoATJ81JYXz
# 11           Chile Top 50  spotify:playlist:37i9dQZEVXbL0GavIqMTeb
# 12       Indonesia Top 50  spotify:playlist:37i9dQZEVXbObFQZ3JLcXt
# 13          France Top 50  spotify:playlist:37i9dQZEVXbIPWwFssbupI
# 14     Philippines Top 50  spotify:playlist:37i9dQZEVXbNBz9cRCSFkY
# 15          Norway Top 50  spotify:playlist:37i9dQZEVXbJvfa0Yxg7E7
# 16           India Top 50  spotify:playlist:37i9dQZEVXbLZ52XmnySJg
# 17        Colombia Top 50  spotify:playlist:37i9dQZEVXbOa2lmxNORXQ
# 18          Turkey Top 50  spotify:playlist:37i9dQZEVXbIVYVBNw9D5K
# 19   United States Top 50  spotify:playlist:37i9dQZEVXbLRQDuF5jeBp
# 20            Peru Top 50  spotify:playlist:37i9dQZEVXbJfdy5b0KP7W
# 21  United Kingdom Top 50  spotify:playlist:37i9dQZEVXbLnolsZ8PSNw
# 22         Finland Top 50  spotify:playlist:37i9dQZEVXbMxcczTSoGwZ
# 23         Ireland Top 50  spotify:playlist:37i9dQZEVXbKM896FDX8L1
# 24         Denmark Top 50  spotify:playlist:37i9dQZEVXbL3J0k32lWnN
# 25        Paraguay Top 50  spotify:playlist:37i9dQZEVXbNOUPGj7tW6T
# 26          Canada Top 50  spotify:playlist:37i9dQZEVXbKj23U1GF4IR
# 27          Taiwan Top 50  spotify:playlist:37i9dQZEVXbMnZEatlMSiu
# 28          Poland Top 50  spotify:playlist:37i9dQZEVXbN6itCcaL3Tt
# 29         Belgium Top 50  spotify:playlist:37i9dQZEVXbJNSeeHswcKB
# 30        Thailand Top 50  spotify:playlist:37i9dQZEVXbMnz8KIWsvf9
# 31       Singapore Top 50  spotify:playlist:37i9dQZEVXbK4gjvS1FjPY
# 32        Malaysia Top 50  spotify:playlist:37i9dQZEVXbJlfUljuZExa
# 33         Ecuador Top 50  spotify:playlist:37i9dQZEVXbJlM6nvL1nD1
# 34        Portugal Top 50  spotify:playlist:37i9dQZEVXbKyJS56d1pgi
# 35          Panama Top 50  spotify:playlist:37i9dQZEVXbKypXHVwk1f0
# 36         Uruguay Top 50  spotify:playlist:37i9dQZEVXbMJJi3wgRbAy
# 37       Guatemala Top 50  spotify:playlist:37i9dQZEVXbLy5tBFyQvd4
# 38         Hungary Top 50  spotify:playlist:37i9dQZEVXbNHwMxAkvmF8
# 39         Bolivia Top 50  spotify:playlist:37i9dQZEVXbJqfMFK4d691
# 40         Vietnam Top 50  spotify:playlist:37i9dQZEVXbLdGSmz6xilI
# 41       Hong Kong Top 50  spotify:playlist:37i9dQZEVXbLwpL8TjsxOG
# 42     Hong Kong Viral 50  spotify:playlist:37i9dQZEVXbKXd6qahcpCg
#
#            Owners
# 0   spotifycharts
# 1   spotifycharts
# 2   spotifycharts
# 3   spotifycharts
# 4   spotifycharts
# 5   spotifycharts
# 6   spotifycharts
# 7   spotifycharts
# 8   spotifycharts
# 9   spotifycharts
# 10  spotifycharts
# 11  spotifycharts
# 12  spotifycharts
# 13  spotifycharts
# 14  spotifycharts
# 15  spotifycharts
# 16  spotifycharts
# 17  spotifycharts
# 18  spotifycharts
# 19  spotifycharts
# 20  spotifycharts
# 21  spotifycharts
# 22  spotifycharts
# 23  spotifycharts
# 24  spotifycharts
# 25  spotifycharts
# 26  spotifycharts
# 27  spotifycharts
# 28  spotifycharts
# 29  spotifycharts
# 30  spotifycharts
# 31  spotifycharts
# 32  spotifycharts
# 33  spotifycharts
# 34  spotifycharts
# 35  spotifycharts
# 36  spotifycharts
# 37  spotifycharts
# 38  spotifycharts
# 39  spotifycharts
# 40  spotifycharts
# 41  spotifycharts
# 42  spotifycharts

# %%
tracks = []
p_id2=[]
test = []
p_name = []
t_ids = []
tracker=[]
p_list=final_playists_df["Playlist_ID"]
data=p_list.str.split(":")
for x in data:
    id =(x[2])
    p_id2.append(id)

for x in p_id2:
    response_json=spotify.user_playlist_tracks("spotifycharts", x)
    rank=1
    cur_play = final_playists_df.loc[final_playists_df["Playlist_ID"] == f"spotify:playlist:{x}"]["Playlist Name"].unique()[0]
    counter = 0
    for i,t in enumerate (response_json["items"]):
        name=(t["track"]["name"])
        t_id=(t["track"]["id"])
        tracks.append(name)
        t_ids.append(t_id)
        test.append(x)
        p_name.append(cur_play)
        rank = rank + 1
        tracker.append(counter+1)
        counter+=1
        if (rank == 6):
            break

# %%
music_df = pd.DataFrame({
    "Playlist Name" : p_name,
    "Playlist ID" : test,
    "Song" : tracks,
    "ID":t_ids,
    "Rank":rank
})
music_df["Playlist Name"] = music_df["Playlist Name"].replace({'United States Top 50' : 'US Top 50', 'United Kingdom Top 50' : 'UK Top 50', 'Hong Kong Viral 50': 'HK Viral 50'})
music_df
# Out:
#      Playlist Name             Playlist ID               Song  \
# 0    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Dance Monkey
# 1    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Lucid Dreams
# 2    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            ROXANNE
# 3    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            Circles
# 4    Global Top 50  37i9dQZEVXbMDoHDwVN2tF           Memories
# ..             ...                     ...                ...
# 210    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Lost in the Woods
# 211    HK Viral 50  37i9dQZEVXbKXd6qahcpCg            Falling
# 212    HK Viral 50  37i9dQZEVXbKXd6qahcpCg   Into the Unknown
# 213    HK Viral 50  37i9dQZEVXbKXd6qahcpCg       All Is Found
# 214    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Bauhinia Rhapsody
#
#                          ID  Rank
# 0    1rgnBhdG2JDFTbYkYRZAku     6
# 1    285pBltuF7vW8TeWk8hdRR     6
# 2    696DnlkuDOXcMAnKlTgXXK     6
# 3    21jGcNKet2qwijlDFuPiPb     6
# 4    2b8fOow8UzyDFAE27YhOZM     6
# ..                      ...   ...
# 210  7namdlOhbtsc8FvoSafOQt     6
# 211  4TnjEaWOeW0eKTKIEvJyCa     6
# 212  3Z0oQ8r78OUaHvGPiDBR3W     6
# 213  61HVbcNeRACZpyvHrc3AnD     6
# 214  6gTAS57L0jTyk4OrenilJS     6
#
# [215 rows x 5 columns]

# %%
country = []
Range=music_df["Playlist Name"].str.split(" ")[:,]

for x in Range:
    n_c=(x[0])
    country.append(n_c)
music_df["Country"]=country
music_df
music_df.to_csv("music.csv")

music_df
# Out:
#      Playlist Name             Playlist ID               Song  \
# 0    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Dance Monkey
# 1    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Lucid Dreams
# 2    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            ROXANNE
# 3    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            Circles
# 4    Global Top 50  37i9dQZEVXbMDoHDwVN2tF           Memories
# ..             ...                     ...                ...
# 210    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Lost in the Woods
# 211    HK Viral 50  37i9dQZEVXbKXd6qahcpCg            Falling
# 212    HK Viral 50  37i9dQZEVXbKXd6qahcpCg   Into the Unknown
# 213    HK Viral 50  37i9dQZEVXbKXd6qahcpCg       All Is Found
# 214    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Bauhinia Rhapsody
#
#                          ID  Rank Country
# 0    1rgnBhdG2JDFTbYkYRZAku     6  Global
# 1    285pBltuF7vW8TeWk8hdRR     6  Global
# 2    696DnlkuDOXcMAnKlTgXXK     6  Global
# 3    21jGcNKet2qwijlDFuPiPb     6  Global
# 4    2b8fOow8UzyDFAE27YhOZM     6  Global
# ..                      ...   ...     ...
# 210  7namdlOhbtsc8FvoSafOQt     6      HK
# 211  4TnjEaWOeW0eKTKIEvJyCa     6      HK
# 212  3Z0oQ8r78OUaHvGPiDBR3W     6      HK
# 213  61HVbcNeRACZpyvHrc3AnD     6      HK
# 214  6gTAS57L0jTyk4OrenilJS     6      HK
#
# [215 rows x 6 columns]

# %%
m_country=["Hong","Netherlands","Russia","Australia","Canada","France","Japan","Germany","US", "UK"]
final_music_1=music_df.loc[music_df["Country"].isin(m_country)]
spotify_top_df =final_music_1.reset_index()

spotify_top_df
# Out:
#     index       Playlist Name             Playlist ID  \
# 0      15      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 1      16      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 2      17      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 3      18      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 4      19      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 5      25  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 6      26  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 7      27  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 8      28  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 9      29  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 10     35    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 11     36    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 12     37    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 13     38    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 14     39    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 15     45        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 16     46        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 17     47        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 18     48        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 19     49        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 20     65       France Top 50  37i9dQZEVXbIPWwFssbupI
# 21     66       France Top 50  37i9dQZEVXbIPWwFssbupI
# 22     67       France Top 50  37i9dQZEVXbIPWwFssbupI
# 23     68       France Top 50  37i9dQZEVXbIPWwFssbupI
# 24     69       France Top 50  37i9dQZEVXbIPWwFssbupI
# 25     95           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 26     96           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 27     97           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 28     98           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 29     99           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 30    105           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 31    106           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 32    107           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 33    108           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 34    109           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 35    130       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 36    131       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 37    132       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 38    133       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 39    134       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 40    205    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 41    206    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 42    207    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 43    208    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 44    209    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
#
#                                         Song                      ID  Rank  \
# 0                                KEIN SCHLAF  6416zJN0FGPmh1Ph4BH2h3     6
# 1                                       COLT  76IVpz47q3ghkxoUeTTEKb     6
# 2                                     Roller  6hw1Sy9wZ8UCxYGdpKrU6M     6
# 3              Der Bratan bleibt der gleiche  2M39v73rNJmAXUXIW0oagP     6
# 4                               Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     6
# 5                               Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     6
# 6                               Lucid Dreams  285pBltuF7vW8TeWk8hdRR     6
# 7                               Pa Olvidarte  1RO8Q3w2Jkir8cvvGEApI0     6
# 8                                    ROXANNE  696DnlkuDOXcMAnKlTgXXK     6
# 9                                   Memories  2b8fOow8UzyDFAE27YhOZM     6
# 10                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     6
# 11                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     6
# 12                                   ROXANNE  696DnlkuDOXcMAnKlTgXXK     6
# 13                                   Circles  21jGcNKet2qwijlDFuPiPb     6
# 14                           Don't Start Now  6WrI0LAC5M1Rw2MnX2ZvEg     6
# 15                                 Pretender  58dxGXavrcagRqA58fNB0Z     6
# 16                                 Hakujitsu  0mNO3xUzjsI17GXO1DRFCH     6
# 17                                        宿命  2yozZfRYHP7Elsymghu5t3     6
# 18                                    イエスタデイ  3S3DDZrPOYTirleXRyHnNM     6
# 19                                     ノーダウト  5DMEvbg3gUmiR5HIBWdveV     6
# 20                            Ne reviens pas  4TnFANpjVwVKWzkxNzIyFH     6
# 21                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     6
# 22                                   Popopop  18HNGxDOcshRU2Hdu8tMOM     6
# 23                      Mayday (feat. Ninho)  1SVuEeerYIwjCRsF5MGzX3     6
# 24                                    Jamais  2MCAs3ttHSuDm1RHL0rqTF     6
# 25                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     6
# 26  Bandit (with YoungBoy Never Broke Again)  6Gg1gjgKi2AK4e0qzsR7sd     6
# 27                                   Robbery  6Hj9jySrnFppAI0sEMCZpJ     6
# 28                                   Legends  1Knctxx9vGZxpZfF66BIEa     6
# 29                    All Girls Are The Same  4VXIryQMWpIdGgYR4TrjT1     6
# 30                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     6
# 31                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     6
# 32           All I Want for Christmas Is You  0bYg9bo50gSsH3LtXe2SQn     6
# 33     Own It (feat. Ed Sheeran & Burna Boy)  07s9NNOT0sZQp7TyolLLgu     6
# 34                            Last Christmas  2FRnf9qhLbvw8fu4IBXx78     6
# 35                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     6
# 36                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     6
# 37  Bandit (with YoungBoy Never Broke Again)  6Gg1gjgKi2AK4e0qzsR7sd     6
# 38                                   ROXANNE  696DnlkuDOXcMAnKlTgXXK     6
# 39                                   Robbery  6Hj9jySrnFppAI0sEMCZpJ     6
# 40                                  Señorita  6v3KW9xbzN5yKLt9YKDYA2     6
# 41                                  Memories  2b8fOow8UzyDFAE27YhOZM     6
# 42                                   Circles  21jGcNKet2qwijlDFuPiPb     6
# 43                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     6
# 44                       everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ     6
#
#         Country
# 0       Germany
# 1       Germany
# 2       Germany
# 3       Germany
# 4       Germany
# 5   Netherlands
# 6   Netherlands
# 7   Netherlands
# 8   Netherlands
# 9   Netherlands
# 10    Australia
# 11    Australia
# 12    Australia
# 13    Australia
# 14    Australia
# 15        Japan
# 16        Japan
# 17        Japan
# 18        Japan
# 19        Japan
# 20       France
# 21       France
# 22       France
# 23       France
# 24       France
# 25           US
# 26           US
# 27           US
# 28           US
# 29           US
# 30           UK
# 31           UK
# 32           UK
# 33           UK
# 34           UK
# 35       Canada
# 36       Canada
# 37       Canada
# 38       Canada
# 39       Canada
# 40         Hong
# 41         Hong
# 42         Hong
# 43         Hong
# 44         Hong

# %%
spotify_top_df = spotify_top_df.rename(columns={'Song':'Name'})

# %%
spot_album_list = []
spot_genre_list = []
spot_artist_list = []

for song in spotify_top_df["Name"]:
    media = 'media=music'
    entity = 'entity=song'
    limit = 'limit=1'

    try:
        artist = f"term={song}"
        url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit
        
        response = requests.get(url).json()
        spot_genre_list.append(response["results"][-1]['primaryGenreName'])
        spot_album_list.append(response["results"][-1]["collectionName"])
        spot_artist_list.append(response["results"][-1]['artistName'])
    except:
        text = song
        head, sep, tail = text.partition('(')
        
        artist = f"term={head}"
        url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit
        
        response = requests.get(url).json()
        spot_genre_list.append(response["results"][-1]['primaryGenreName'])
        spot_album_list.append(response["results"][-1]["collectionName"])
        spot_artist_list.append(response["results"][-1]['artistName'])        
        continue

# %%
spotify_top_df["Genre"] = spot_genre_list
spotify_top_df["Album"] = spot_album_list
spotify_top_df["Artist"] = spot_artist_list
spotify_top_df["Source"] = 'Spotify'
spotify_top_df['Rank'] = np.arange(len(spotify_top_df))
spotify_top_df['Rank'] = spotify_top_df['Rank'] % 5 + 1

spotify_top_df = spotify_top_df[['Country', 'Name', 'Artist', 'Album', 'Genre', 'Rank', 'Source']]
spotify_top_df['Country'] = spotify_top_df['Country'].replace({'Hong' : 'Hong Kong'}) 


spotify_top_df
# Out:
#         Country                                      Name  \
# 0       Germany                               KEIN SCHLAF
# 1       Germany                                      COLT
# 2       Germany                                    Roller
# 3       Germany             Der Bratan bleibt der gleiche
# 4       Germany                              Dance Monkey
# 5   Netherlands                              Dance Monkey
# 6   Netherlands                              Lucid Dreams
# 7   Netherlands                              Pa Olvidarte
# 8   Netherlands                                   ROXANNE
# 9   Netherlands                                  Memories
# 10    Australia                              Lucid Dreams
# 11    Australia                              Dance Monkey
# 12    Australia                                   ROXANNE
# 13    Australia                                   Circles
# 14    Australia                           Don't Start Now
# 15        Japan                                 Pretender
# 16        Japan                                 Hakujitsu
# 17        Japan                                        宿命
# 18        Japan                                    イエスタデイ
# 19        Japan                                     ノーダウト
# 20       France                            Ne reviens pas
# 21       France                              Dance Monkey
# 22       France                                   Popopop
# 23       France                      Mayday (feat. Ninho)
# 24       France                                    Jamais
# 25           US                              Lucid Dreams
# 26           US  Bandit (with YoungBoy Never Broke Again)
# 27           US                                   Robbery
# 28           US                                   Legends
# 29           US                    All Girls Are The Same
# 30           UK                              Dance Monkey
# 31           UK                              Lucid Dreams
# 32           UK           All I Want for Christmas Is You
# 33           UK     Own It (feat. Ed Sheeran & Burna Boy)
# 34           UK                            Last Christmas
# 35       Canada                              Lucid Dreams
# 36       Canada                              Dance Monkey
# 37       Canada  Bandit (with YoungBoy Never Broke Again)
# 38       Canada                                   ROXANNE
# 39       Canada                                   Robbery
# 40    Hong Kong                                  Señorita
# 41    Hong Kong                                  Memories
# 42    Hong Kong                                   Circles
# 43    Hong Kong                              Lucid Dreams
# 44    Hong Kong                       everything i wanted
#
#                                      Artist  \
# 0                                       LGM
# 1                                 Colt Ford
# 2                                April Wine
# 3                               Capital Bra
# 4                               Tones and I
# 5                               Tones and I
# 6                                Juice WRLD
# 7     ChocQuibTown, Zion & Lennox & Farruko
# 8                            Arizona Zervas
# 9                                  Maroon 5
# 10                               Juice WRLD
# 11                              Tones and I
# 12                           Arizona Zervas
# 13                              Post Malone
# 14                                 Dua Lipa
# 15                               Steve Aoki
# 16                                 King Gnu
# 17                       Yasuharu Takanashi
# 18                              The Beatles
# 19                                 No Doubt
# 20                           Salomé Leclerc
# 21                              Tones and I
# 22                             musiqman Jr.
# 23                                      SCH
# 24                     Charlotte Gainsbourg
# 25                               Juice WRLD
# 26  Juice WRLD & YoungBoy Never Broke Again
# 27                               Juice WRLD
# 28                               Juice WRLD
# 29                               Juice WRLD
# 30                              Tones and I
# 31                               Juice WRLD
# 32                             Mariah Carey
# 33                                  Stormzy
# 34                                    Wham!
# 35                               Juice WRLD
# 36                              Tones and I
# 37  Juice WRLD & YoungBoy Never Broke Again
# 38                           Arizona Zervas
# 39                               Juice WRLD
# 40            Shawn Mendes & Camila Cabello
# 41                                 Maroon 5
# 42                              Post Malone
# 43                               Juice WRLD
# 44                            Billie Eilish
#
#                                                 Album          Genre  Rank  \
# 0                                Kein Schlaf - Single    Hip-Hop/Rap     1
# 1        Declaration of Independence (Deluxe Edition)        Country     2
# 2            Classic Masters: April Wine (Remastered)           Rock     3
# 3              Der Bratan bleibt der gleiche - Single    Hip-Hop/Rap     4
# 4                            The Kids Are Coming - EP    Alternative     5
# 5                            The Kids Are Coming - EP    Alternative     1
# 6                             Goodbye & Good Riddance    Hip-Hop/Rap     2
# 7   Pa Olvidarte (Remix) [feat. Manuel Turizo] - S...  Urbano latino     3
# 8                                    ROXANNE - Single    Hip-Hop/Rap     4
# 9                                   Memories - Single            Pop     5
# 10                            Goodbye & Good Riddance    Hip-Hop/Rap     1
# 11                           The Kids Are Coming - EP    Alternative     2
# 12                                   ROXANNE - Single    Hip-Hop/Rap     3
# 13                               Hollywood's Bleeding    Hip-Hop/Rap     4
# 14                           Don't Start Now - Single            Pop     5
# 15        Pretender (feat. Lil Yachty & AJR) - Single          Dance     1
# 16                                 Hakujitsu - Single          J-Pop     2
# 17             "Fairy Tail" Original Soundtrack Vol.1          Anime     3
# 18                                   1 (2015 Version)           Rock     4
# 19                              The Singles 1992-2003            Pop     5
# 20                                    Sous les arbres     French Pop     1
# 21                           The Kids Are Coming - EP    Alternative     2
# 22                                       Musiqruisin'       R&B/Soul     3
# 23                                            Rooftop    Hip-Hop/Rap     4
# 24                                               5:55    Alternative     5
# 25                            Goodbye & Good Riddance    Hip-Hop/Rap     1
# 26                                    Bandit - Single    Hip-Hop/Rap     2
# 27                                Death Race for Love    Hip-Hop/Rap     3
# 28                                   Legends - Single    Hip-Hop/Rap     4
# 29                            Goodbye & Good Riddance    Hip-Hop/Rap     5
# 30                           The Kids Are Coming - EP    Alternative     1
# 31                            Goodbye & Good Riddance    Hip-Hop/Rap     2
# 32                                    Merry Christmas        Holiday     3
# 33                                  Heavy Is The Head    Hip-Hop/Rap     4
# 34                            Last Christmas - Single        Holiday     5
# 35                            Goodbye & Good Riddance    Hip-Hop/Rap     1
# 36                           The Kids Are Coming - EP    Alternative     2
# 37                                    Bandit - Single    Hip-Hop/Rap     3
# 38                                   ROXANNE - Single    Hip-Hop/Rap     4
# 39                                Death Race for Love    Hip-Hop/Rap     5
# 40                                  Señorita - Single            Pop     1
# 41                                  Memories - Single            Pop     2
# 42                               Hollywood's Bleeding    Hip-Hop/Rap     3
# 43                            Goodbye & Good Riddance    Hip-Hop/Rap     4
# 44                       everything i wanted - Single    Alternative     5
#
#      Source
# 0   Spotify
# 1   Spotify
# 2   Spotify
# 3   Spotify
# 4   Spotify
# 5   Spotify
# 6   Spotify
# 7   Spotify
# 8   Spotify
# 9   Spotify
# 10  Spotify
# 11  Spotify
# 12  Spotify
# 13  Spotify
# 14  Spotify
# 15  Spotify
# 16  Spotify
# 17  Spotify
# 18  Spotify
# 19  Spotify
# 20  Spotify
# 21  Spotify
# 22  Spotify
# 23  Spotify
# 24  Spotify
# 25  Spotify
# 26  Spotify
# 27  Spotify
# 28  Spotify
# 29  Spotify
# 30  Spotify
# 31  Spotify
# 32  Spotify
# 33  Spotify
# 34  Spotify
# 35  Spotify
# 36  Spotify
# 37  Spotify
# 38  Spotify
# 39  Spotify
# 40  Spotify
# 41  Spotify
# 42  Spotify
# 43  Spotify
# 44  Spotify

# %%
genre_list = []

for song in lastfm_top_df["Name"]:
    
    media = 'media=music'
    entity = 'entity=song'
    limit = 'limit=1'
    try:
            artist = f"term={song}"
            url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit

            response = requests.get(url).json()
            genre_list.append(response["results"][-1]['primaryGenreName'])
    except:
            text = song
            head, sep, tail = text.partition('(')

            artist = f"term={head}"
            url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit

            response = requests.get(url).json()
            genre_list.append(response["results"][-1]['primaryGenreName'])      
            continue

# %%
lastfm_top_df["Genre"] = genre_list
lastfm_top_df = lastfm_top_df[['Country', 'Name', 'Artist', 'Album', 'Genre', 'Rank', 'Source']]

lastfm_top_df
# Out:
#         Country                             Name                    Artist  \
# 0     Hong Kong                            Hello                     Adele
# 1     Hong Kong               Can't Feel My Face                The Weeknd
# 2     Hong Kong                       Photograph                Ed Sheeran
# 3     Hong Kong                Thinking Out Loud                Ed Sheeran
# 4     Hong Kong                     Shape of You                Ed Sheeran
# 5   Netherlands                           Africa                      Toto
# 6   Netherlands                 Sultans of Swing              Dire Straits
# 7   Netherlands                            Hello                     Adele
# 8   Netherlands          Smells Like Teen Spirit                   Nirvana
# 9   Netherlands                       Wonderwall                     Oasis
# 10    Australia       The Less I Know the Better               Tame Impala
# 11    Australia                   Mr. Brightside               The Killers
# 12    Australia               Can't Feel My Face                The Weeknd
# 13    Australia                    Hotline Bling                     Drake
# 14    Australia                    Let It Happen               Tame Impala
# 15       Canada               Can't Feel My Face                The Weeknd
# 16       Canada                    Hotline Bling                     Drake
# 17       Canada                   Mr. Brightside               The Killers
# 18       Canada          Smells Like Teen Spirit                   Nirvana
# 19       Canada       The Less I Know the Better               Tame Impala
# 20       France          Smells Like Teen Spirit                   Nirvana
# 21       France                            Creep                 Radiohead
# 22       France                             Come                      Jain
# 23       France                       Wonderwall                     Oasis
# 24       France                     Karma Police                 Radiohead
# 25        Japan                            ロビンソン                      スピッツ
# 26        Japan                            花束を君に                    宇多田ヒカル
# 27        Japan                              新宝島                   サカナクション
# 28        Japan                             リライト  ASIAN KUNG-FU GENERATION
# 29        Japan                                道                    宇多田ヒカル
# 30           UK                   Mr. Brightside               The Killers
# 31           UK                           Africa                      Toto
# 32           UK  All I Want for Christmas Is You              Mariah Carey
# 33           UK          Smells Like Teen Spirit                   Nirvana
# 34           UK                Seven Nation Army         The White Stripes
# 35      Germany          Smells Like Teen Spirit                   Nirvana
# 36      Germany                           Africa                      Toto
# 37      Germany                   Mr. Brightside               The Killers
# 38      Germany                  Come as You Are                   Nirvana
# 39      Germany                            Hello                     Adele
# 40           US               Can't Feel My Face                The Weeknd
# 41           US                    Hotline Bling                     Drake
# 42           US       The Less I Know the Better               Tame Impala
# 43           US                   Mr. Brightside               The Killers
# 44           US                            Hello                     Adele
#
#                                           Album        Genre  Rank  Source
# 0                                            25          Pop     1  LastFM
# 1                     Beauty Behind the Madness     R&B/Soul     2  LastFM
# 2                                             x          Pop     3  LastFM
# 3                                             x          Pop     4  LastFM
# 4                                    ÷ (Deluxe)          Pop     5  LastFM
# 5                                       Toto IV         Rock     1  LastFM
# 6                                  Dire Straits         Rock     2  LastFM
# 7                                            25          Pop     3  LastFM
# 8                                     Nevermind         Rock     4  LastFM
# 9             (What's the Story) Morning Glory?  Alternative     5  LastFM
# 10                                     Currents  Alternative     1  LastFM
# 11                                     Hot Fuss         Rock     2  LastFM
# 12                    Beauty Behind the Madness     R&B/Soul     3  LastFM
# 13                                        Views  Hip-Hop/Rap     4  LastFM
# 14                                     Currents  Alternative     5  LastFM
# 15                    Beauty Behind the Madness     R&B/Soul     1  LastFM
# 16                                        Views  Hip-Hop/Rap     2  LastFM
# 17                                     Hot Fuss         Rock     3  LastFM
# 18                                    Nevermind         Rock     4  LastFM
# 19                                     Currents  Alternative     5  LastFM
# 20                                    Nevermind         Rock     1  LastFM
# 21                                  Pablo Honey  Alternative     2  LastFM
# 22                                       Zanaka          Pop     3  LastFM
# 23            (What's the Story) Morning Glory?  Alternative     4  LastFM
# 24                                  OK Computer  Alternative     5  LastFM
# 25                                         ハチミツ          Pop     1  LastFM
# 26                                        花束を君に        J-Pop     2  LastFM
# 27                                          新宝島         Rock     3  LastFM
# 28                                         ソルファ        Anime     4  LastFM
# 29  Hikaru Utada Laughter in the Dark Tour 2018  Hip-Hop/Rap     5  LastFM
# 30                                     Hot Fuss         Rock     1  LastFM
# 31                                      Toto IV         Rock     2  LastFM
# 32                              Merry Christmas      Holiday     3  LastFM
# 33                                    Nevermind         Rock     4  LastFM
# 34                                     Elephant  Alternative     5  LastFM
# 35                                    Nevermind         Rock     1  LastFM
# 36                                      Toto IV         Rock     2  LastFM
# 37                                     Hot Fuss         Rock     3  LastFM
# 38                                    Nevermind         Rock     4  LastFM
# 39                                           25          Pop     5  LastFM
# 40                    Beauty Behind the Madness     R&B/Soul     1  LastFM
# 41                                        Views  Hip-Hop/Rap     2  LastFM
# 42                                     Currents  Alternative     3  LastFM
# 43                                     Hot Fuss         Rock     4  LastFM
# 44                                           25          Pop     5  LastFM

# %%
music = [apple_top_df, lastfm_top_df, spotify_top_df]

merge_df = pd.concat(music)

merge_df
# Out:
#       Country                 Name                           Artist  \
# 0   Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1   Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2   Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3   Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4   Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
# ..        ...                  ...                              ...
# 40  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 41  Hong Kong             Memories                         Maroon 5
# 42  Hong Kong              Circles                      Post Malone
# 43  Hong Kong         Lucid Dreams                       Juice WRLD
# 44  Hong Kong  everything i wanted                    Billie Eilish
#
#                                                 Album           Genre  Rank  \
# 0                                   Señorita - Single             Pop     1
# 1   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                       說好不哭 - Single             Pop     3
# 3   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                        讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
# ..                                                ...             ...   ...
# 40                                  Señorita - Single             Pop     1
# 41                                  Memories - Single             Pop     2
# 42                               Hollywood's Bleeding     Hip-Hop/Rap     3
# 43                            Goodbye & Good Riddance     Hip-Hop/Rap     4
# 44                       everything i wanted - Single     Alternative     5
#
#      Source
# 0     Apple
# 1     Apple
# 2     Apple
# 3     Apple
# 4     Apple
# ..      ...
# 40  Spotify
# 41  Spotify
# 42  Spotify
# 43  Spotify
# 44  Spotify
#
# [135 rows x 7 columns]

# %%
spotify_id = []
for index, row in merge_df.iterrows():
    try:
        res = spotify.search(row["Name"], type="track", limit=1)
        spotify_id.append(res["tracks"]["items"][0]["id"])
    except:
        text = row["Name"]
        head, sep, tail = text.partition('(')
        res = spotify.search(head, type="track", limit=1)
        spotify_id.append(res["tracks"]["items"][0]["id"])
        continue
        
merge_df["Spotify ID"] = spotify_id
merge_df.head()
# Out:
#      Country                 Name                           Artist  \
# 0  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1  Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2  Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3  Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4  Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
#
#                                                Album           Genre  Rank  \
# 0                                  Señorita - Single             Pop     1
# 1  Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                      說好不哭 - Single             Pop     3
# 3  Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                       讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
#
#   Source              Spotify ID
# 0  Apple  0TK2YIli7K1leLovkQiNik
# 1  Apple  3Z0oQ8r78OUaHvGPiDBR3W
# 2  Apple  56wVfJKtnwlSZtC4NVgIrf
# 3  Apple  50WeOnXhM1H7AZEeIDoWfZ
# 4  Apple  7nIxo0dE9d4FBwPYhmdQae

# %%
danceability = []
energy = []
key = []
loudness = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []

track_features = spotify.audio_features(tracks='3Z0oQ8r78OUaHvGPiDBR3W')

pprint(track_features)
# Out:
# [{'acousticness': 0.849,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Z0oQ8r78OUaHvGPiDBR3W',
#   'danceability': 0.323,
#   'duration_ms': 194848,
#   'energy': 0.405,
#   'id': '3Z0oQ8r78OUaHvGPiDBR3W',
#   'instrumentalness': 0.000544,
#   'key': 10,
#   'liveness': 0.138,
#   'loudness': -8.533,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'tempo': 145.104,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/3Z0oQ8r78OUaHvGPiDBR3W',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3Z0oQ8r78OUaHvGPiDBR3W',
#   'valence': 0.274}]

# %%
for index, row in merge_df.iterrows():
    try:
        track_features = spotify.audio_features(tracks=row['Spotify ID'])
        danceability.append(track_features[0]["danceability"])
        energy.append(track_features[0]["energy"])
        key.append(track_features[0]["key"])
        loudness.append(track_features[0]["loudness"])
        speechiness.append(track_features[0]["speechiness"])
        acousticness.append(track_features[0]["acousticness"])
        instrumentalness.append(track_features[0]["instrumentalness"])
        liveness.append(track_features[0]["liveness"])
        valence.append(track_features[0]["valence"])
        tempo.append(track_features[0]["tempo"])
        duration_ms.append(track_features[0]["duration_ms"])
    except:
        print(f"Couldn't find details for {row['Spotify ID']}")
        continue

# %%
merge_df
# Out:
#       Country                 Name                           Artist  \
# 0   Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1   Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2   Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3   Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4   Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
# ..        ...                  ...                              ...
# 40  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 41  Hong Kong             Memories                         Maroon 5
# 42  Hong Kong              Circles                      Post Malone
# 43  Hong Kong         Lucid Dreams                       Juice WRLD
# 44  Hong Kong  everything i wanted                    Billie Eilish
#
#                                                 Album           Genre  Rank  \
# 0                                   Señorita - Single             Pop     1
# 1   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                       說好不哭 - Single             Pop     3
# 3   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                        讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
# ..                                                ...             ...   ...
# 40                                  Señorita - Single             Pop     1
# 41                                  Memories - Single             Pop     2
# 42                               Hollywood's Bleeding     Hip-Hop/Rap     3
# 43                            Goodbye & Good Riddance     Hip-Hop/Rap     4
# 44                       everything i wanted - Single     Alternative     5
#
#      Source              Spotify ID
# 0     Apple  0TK2YIli7K1leLovkQiNik
# 1     Apple  3Z0oQ8r78OUaHvGPiDBR3W
# 2     Apple  56wVfJKtnwlSZtC4NVgIrf
# 3     Apple  50WeOnXhM1H7AZEeIDoWfZ
# 4     Apple  7nIxo0dE9d4FBwPYhmdQae
# ..      ...                     ...
# 40  Spotify  0TK2YIli7K1leLovkQiNik
# 41  Spotify  2b8fOow8UzyDFAE27YhOZM
# 42  Spotify  21jGcNKet2qwijlDFuPiPb
# 43  Spotify  285pBltuF7vW8TeWk8hdRR
# 44  Spotify  3ZCTVFBt2Brf31RLEnCkWJ
#
# [135 rows x 8 columns]

# %%
output_file = merge_df.to_csv('track_analysis.csv')
