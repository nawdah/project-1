# %%
# %matplotlib inline

import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

apple_top5 = pd.read_csv('../Resources/appleAPI_data.csv')
lastfm_top5 = pd.read_csv('../Resources/LastFM_data.csv')

apple_top5.head()
lastfm_top5 = pd.DataFrame({
    "Country" : lastfm_top5["Country"],
    "Name" : lastfm_top5["Song Title"],
    "Artist" : lastfm_top5["Artist(s)"],
    "Album" : lastfm_top5["Album"],
    "Rank" : lastfm_top5["Rank"],
    "Source" : lastfm_top5["Source"]
})
apple_top5.head()
# Out:
#      Country              Name                           Artist  \
# 0  Hong Kong  Into the Unknown            Idina Menzel & AURORA
# 1  Hong Kong          Señorita    Shawn Mendes & Camila Cabello
# 2  Hong Kong              說好不哭                         周杰倫 & 阿信
# 3  Hong Kong     Show Yourself  Idina Menzel & Evan Rachel Wood
# 4  Hong Kong          Memories                            魔力紅樂團
#
#                                                Album       Genre  Rank Source
# 0  Frozen 2 (Original Motion Picture Soundtrack /...  Soundtrack     1  Apple
# 1                                  Señorita - Single         Pop     2  Apple
# 2                                      說好不哭 - Single         Pop     3  Apple
# 3  Frozen 2 (Original Motion Picture Soundtrack /...  Soundtrack     4  Apple
# 4                                  Memories - Single         Pop     5  Apple

# %%
import requests
import json

genre_list = []

for song in lastfm_top5["Name"]:
    artist = f"term={song}"
    media = 'media=music'
    entity = 'entity=song'
    limit = 'limit=1'

    url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit
    response = requests.get(url).json()

    genre_list.append(response["results"][-1]['primaryGenreName'])
# Out:
# 50

# %%
lastfm_top5["Genre"] = genre_list
lastfm_top5 = lastfm_top5[['Country', 'Name', 'Artist', 'Album', 'Genre', 'Rank', 'Source']]

lastfm_top5
# Out:
#         Country                             Name                    Artist  \
# 0     Hong Kong                            Hello                     Adele
# 1     Hong Kong               Can't Feel My Face                The Weeknd
# 2     Hong Kong                       Photograph                Ed Sheeran
# 3     Hong Kong                Thinking Out Loud                Ed Sheeran
# 4     Hong Kong                     Shape of You                Ed Sheeran
# 5   Netherlands                           Africa                      Toto
# 6   Netherlands                 Sultans of Swing              Dire Straits
# 7   Netherlands                            Hello                     Adele
# 8   Netherlands          Smells Like Teen Spirit                   Nirvana
# 9   Netherlands                       Wonderwall                     Oasis
# 10       Russia          Smells Like Teen Spirit                   Nirvana
# 11       Russia                Seven Nation Army         The White Stripes
# 12       Russia                             Numb               Linkin Park
# 13       Russia                            Intro                    The xx
# 14       Russia                       In the End               Linkin Park
# 15    Australia       The Less I Know the Better               Tame Impala
# 16    Australia                   Mr. Brightside               The Killers
# 17    Australia               Can't Feel My Face                The Weeknd
# 18    Australia                    Hotline Bling                     Drake
# 19    Australia                    Let It Happen               Tame Impala
# 20       Canada               Can't Feel My Face                The Weeknd
# 21       Canada                    Hotline Bling                     Drake
# 22       Canada                   Mr. Brightside               The Killers
# 23       Canada          Smells Like Teen Spirit                   Nirvana
# 24       Canada       The Less I Know the Better               Tame Impala
# 25       France          Smells Like Teen Spirit                   Nirvana
# 26       France                            Creep                 Radiohead
# 27       France                             Come                      Jain
# 28       France                       Wonderwall                     Oasis
# 29       France                     Karma Police                 Radiohead
# 30        Japan                            ロビンソン                      スピッツ
# 31        Japan                            花束を君に                    宇多田ヒカル
# 32        Japan                              新宝島                   サカナクション
