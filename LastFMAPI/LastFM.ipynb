# %%
import json
import pandas as pd
import requests
from config import lastfm_api_key

# %%
jsonFormat = '&format=json'

# %%
url = 'http://ws.audioscrobbler.com/2.0/?method=chart.gettoptracks'
url_end = '&api_key=' + lastfm_api_key + jsonFormat

# %%
limit = '5'
countries = ["Hong Kong", "Netherlands", "Australia", 
             "Canada", "France", "Japan", "united kingdom", "Germany", "united states"]
song_list = []
artist_list = []
country_list = []
rank = []

for country in countries:
    top_list = []
    urlgeo = 'http://ws.audioscrobbler.com/2.0/?method=geo.gettoptracks&limit=' + limit + '&country=' + country + url_end
    try:
        lastfm_response = requests.get(urlgeo).json()
        top_list.append(lastfm_response["tracks"]["track"])
        temp_df = pd.DataFrame(top_list)
        for x in range (0,5):
            rank.append(x+1)
            song_list.append(temp_df[x][0]['name'])
            country_list.append(country)
            artist_list.append(temp_df[x][0]['artist']['name'])
    except:
        print(f"Couldn't find {country}")

# %%
top_df=pd.DataFrame({
    "Country" : country_list,
    "Artist(s)" : artist_list,
    "Song Title" : song_list,
    "Rank" : rank
})

top_df["Source"] = "LastFM"

top_df
# Out:
#            Country                 Artist(s)                       Song Title  \
# 0        Hong Kong                     Adele                            Hello
# 1        Hong Kong                The Weeknd               Can't Feel My Face
# 2        Hong Kong                Ed Sheeran                       Photograph
# 3        Hong Kong                Ed Sheeran                Thinking Out Loud
# 4        Hong Kong                Ed Sheeran                     Shape of You
# 5      Netherlands                      Toto                           Africa
# 6      Netherlands              Dire Straits                 Sultans of Swing
# 7      Netherlands                     Adele                            Hello
# 8      Netherlands                   Nirvana          Smells Like Teen Spirit
# 9      Netherlands                     Oasis                       Wonderwall
# 10       Australia               Tame Impala       The Less I Know the Better
# 11       Australia               The Killers                   Mr. Brightside
# 12       Australia                The Weeknd               Can't Feel My Face
# 13       Australia                     Drake                    Hotline Bling
# 14       Australia               Tame Impala                    Let It Happen
# 15          Canada                The Weeknd               Can't Feel My Face
# 16          Canada                     Drake                    Hotline Bling
# 17          Canada               The Killers                   Mr. Brightside
# 18          Canada                   Nirvana          Smells Like Teen Spirit
# 19          Canada               Tame Impala       The Less I Know the Better
# 20          France                   Nirvana          Smells Like Teen Spirit
# 21          France                 Radiohead                            Creep
# 22          France                      Jain                             Come
# 23          France                     Oasis                       Wonderwall
# 24          France                 Radiohead                     Karma Police
# 25           Japan                      スピッツ                            ロビンソン
# 26           Japan                    宇多田ヒカル                            花束を君に
# 27           Japan                   サカナクション                              新宝島
# 28           Japan  ASIAN KUNG-FU GENERATION                             リライト
# 29           Japan                    宇多田ヒカル                                道
# 30  united kingdom               The Killers                   Mr. Brightside
# 31  united kingdom                      Toto                           Africa
# 32  united kingdom              Mariah Carey  All I Want for Christmas Is You
# 33  united kingdom                   Nirvana          Smells Like Teen Spirit
# 34  united kingdom         The White Stripes                Seven Nation Army
# 35         Germany                   Nirvana          Smells Like Teen Spirit
# 36         Germany                      Toto                           Africa
# 37         Germany               The Killers                   Mr. Brightside
# 38         Germany                   Nirvana                  Come as You Are
# 39         Germany                     Adele                            Hello
# 40   united states                The Weeknd               Can't Feel My Face
# 41   united states                     Drake                    Hotline Bling
# 42   united states               Tame Impala       The Less I Know the Better
# 43   united states               The Killers                   Mr. Brightside
# 44   united states                     Adele                            Hello
#
#     Rank  Source
# 0      1  LastFM
# 1      2  LastFM
# 2      3  LastFM
# 3      4  LastFM
# 4      5  LastFM
# 5      1  LastFM
# 6      2  LastFM
# 7      3  LastFM
# 8      4  LastFM
# 9      5  LastFM
# 10     1  LastFM
# 11     2  LastFM
# 12     3  LastFM
# 13     4  LastFM
# 14     5  LastFM
# 15     1  LastFM
# 16     2  LastFM
# 17     3  LastFM
# 18     4  LastFM
# 19     5  LastFM
# 20     1  LastFM
# 21     2  LastFM
# 22     3  LastFM
# 23     4  LastFM
# 24     5  LastFM
# 25     1  LastFM
# 26     2  LastFM
# 27     3  LastFM
# 28     4  LastFM
# 29     5  LastFM
# 30     1  LastFM
# 31     2  LastFM
# 32     3  LastFM
# 33     4  LastFM
# 34     5  LastFM
# 35     1  LastFM
# 36     2  LastFM
# 37     3  LastFM
# 38     4  LastFM
# 39     5  LastFM
# 40     1  LastFM
# 41     2  LastFM
# 42     3  LastFM
# 43     4  LastFM
# 44     5  LastFM

# %%
albums = []
for index, row in top_df.iterrows():
    track_url = f"http://ws.audioscrobbler.com/2.0/?method=track.getInfo&artist={row['Artist(s)']}&track={row['Song Title']}&autocorrect=1" + url_end
    lastfm_response = requests.get(track_url).json()
    albums.append(lastfm_response['track']['album']['title'])

# %%
lastfm_response['track']['album']['title']
# Out:
# '25'

# %%
top_df["Album"] = albums

# %%
top_df.replace(to_replace="united kingdom", value="UK", inplace=True)
top_df.replace(to_replace="united states", value="US", inplace=True)

# %%
top_df
# Out:
#         Country                 Artist(s)                       Song Title  \
# 0     Hong Kong                     Adele                            Hello
# 1     Hong Kong                The Weeknd               Can't Feel My Face
# 2     Hong Kong                Ed Sheeran                       Photograph
# 3     Hong Kong                Ed Sheeran                Thinking Out Loud
# 4     Hong Kong                Ed Sheeran                     Shape of You
# 5   Netherlands                      Toto                           Africa
# 6   Netherlands              Dire Straits                 Sultans of Swing
# 7   Netherlands                     Adele                            Hello
# 8   Netherlands                   Nirvana          Smells Like Teen Spirit
# 9   Netherlands                     Oasis                       Wonderwall
# 10    Australia               Tame Impala       The Less I Know the Better
# 11    Australia               The Killers                   Mr. Brightside
# 12    Australia                The Weeknd               Can't Feel My Face
# 13    Australia                     Drake                    Hotline Bling
# 14    Australia               Tame Impala                    Let It Happen
# 15       Canada                The Weeknd               Can't Feel My Face
# 16       Canada                     Drake                    Hotline Bling
# 17       Canada               The Killers                   Mr. Brightside
# 18       Canada                   Nirvana          Smells Like Teen Spirit
# 19       Canada               Tame Impala       The Less I Know the Better
# 20       France                   Nirvana          Smells Like Teen Spirit
# 21       France                 Radiohead                            Creep
# 22       France                      Jain                             Come
# 23       France                     Oasis                       Wonderwall
# 24       France                 Radiohead                     Karma Police
# 25        Japan                      スピッツ                            ロビンソン
# 26        Japan                    宇多田ヒカル                            花束を君に
# 27        Japan                   サカナクション                              新宝島
# 28        Japan  ASIAN KUNG-FU GENERATION                             リライト
# 29        Japan                    宇多田ヒカル                                道
# 30           UK               The Killers                   Mr. Brightside
# 31           UK                      Toto                           Africa
# 32           UK              Mariah Carey  All I Want for Christmas Is You
# 33           UK                   Nirvana          Smells Like Teen Spirit
# 34           UK         The White Stripes                Seven Nation Army
# 35      Germany                   Nirvana          Smells Like Teen Spirit
# 36      Germany                      Toto                           Africa
# 37      Germany               The Killers                   Mr. Brightside
# 38      Germany                   Nirvana                  Come as You Are
# 39      Germany                     Adele                            Hello
# 40           US                The Weeknd               Can't Feel My Face
# 41           US                     Drake                    Hotline Bling
# 42           US               Tame Impala       The Less I Know the Better
# 43           US               The Killers                   Mr. Brightside
# 44           US                     Adele                            Hello
#
#     Rank  Source                                        Album
# 0      1  LastFM                                           25
# 1      2  LastFM                    Beauty Behind the Madness
# 2      3  LastFM                                            x
# 3      4  LastFM                                            x
# 4      5  LastFM                                   ÷ (Deluxe)
# 5      1  LastFM                                      Toto IV
# 6      2  LastFM                                 Dire Straits
# 7      3  LastFM                                           25
# 8      4  LastFM                                    Nevermind
# 9      5  LastFM            (What's the Story) Morning Glory?
# 10     1  LastFM                                     Currents
# 11     2  LastFM                                     Hot Fuss
# 12     3  LastFM                    Beauty Behind the Madness
# 13     4  LastFM                                        Views
# 14     5  LastFM                                     Currents
# 15     1  LastFM                    Beauty Behind the Madness
# 16     2  LastFM                                        Views
# 17     3  LastFM                                     Hot Fuss
# 18     4  LastFM                                    Nevermind
# 19     5  LastFM                                     Currents
# 20     1  LastFM                                    Nevermind
# 21     2  LastFM                                  Pablo Honey
# 22     3  LastFM                                       Zanaka
# 23     4  LastFM            (What's the Story) Morning Glory?
# 24     5  LastFM                                  OK Computer
# 25     1  LastFM                                         ハチミツ
# 26     2  LastFM                                        花束を君に
# 27     3  LastFM                                          新宝島
# 28     4  LastFM                                         ソルファ
# 29     5  LastFM  Hikaru Utada Laughter in the Dark Tour 2018
# 30     1  LastFM                                     Hot Fuss
# 31     2  LastFM                                      Toto IV
# 32     3  LastFM                              Merry Christmas
# 33     4  LastFM                                    Nevermind
# 34     5  LastFM                                     Elephant
# 35     1  LastFM                                    Nevermind
# 36     2  LastFM                                      Toto IV
# 37     3  LastFM                                     Hot Fuss
# 38     4  LastFM                                    Nevermind
# 39     5  LastFM                                           25
# 40     1  LastFM                    Beauty Behind the Madness
# 41     2  LastFM                                        Views
# 42     3  LastFM                                     Currents
# 43     4  LastFM                                     Hot Fuss
# 44     5  LastFM                                           25

# %%
top_df.to_csv("../Resources/LastFM_data.csv")
