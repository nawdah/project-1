# %% [markdown]
# # In this notebook - we will use the APIs from Apple Music, LastFM, and Spotify to collect the top 5 tracks per region
#
# Leveraging Client and Secret keys, we will authenticate with each of the above platforms and collect data about the top tracks per region.  After collecting the data, the goal is to get information about the tracks, and identify any trends that are presented in the data
#
# # After collecting data from each platform, we will clean and aggregate additional information about the tracks
#
# Each API offers different insights into the data. After collecting the top 5 by region, Apple's API give us a clear genre of each song type.  In an effort to standardize/normalize the data, we will use Apple's API to collect information about the genre
#
# Once that is complete, Spotify's API give us detailed information about the audio features of the track.  We will be reviewing the following data points:
#
# **Danceability** describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least # danceable and 1.0 is most danceable.
#
# **Energy** is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **Pitch Class** = Tonal counterparts:
#     0=C
#     1=C♯
#     2=D
#     3=D♯
#     4=E
#     5=F
#     6=F♯
#     7=G
#     8=G♯
#     9=A
#     10=t or Aor A♯
#     11=e or B
#
# **Loudness** - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# **Speechiness** detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **Accousticness** - a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# **Instrumentalness** - Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# **Liveness** - Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# **Valence** - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
#importing the neccessary libraries we will need to run our data and analysis

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import sys
import csv
import seaborn as sns

from googletrans import Translator 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
import json
from pprint import pprint 

import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

from config import lastfm_api_key, CLIENT_ID, CLIENT_SECRET

# %% [markdown]
# # Using a quick Google Search we found the top countries as it pertains to music.  We then selected the countries that data was readily available for across all of our platforms
#
# Countries include:
# <ul>
#     <li>Hong Kong</li>
#     <li>Netherlands</li>
#     <li>Australia</li>
#     <li>Canada</li>
#     <li>France</li>
#     <li>Japan</li>
#     <li>United Kingdom</li>
#     <li>Germany</li>
#     <li>United States</li>
# </ul>

# %%
#list of countries we narrow down to sort through our data

countries = ['hk', 'nl', 'au', 'ca', 'fr', 'jp', 'gb', 'de', 'us' ]

# %% [markdown]
# # Apple Music API to get the top songs in the above countries

# %%
#create a dataframe that takes in all the top 5 songs from each country on our list

song_list = []
artist_list = []
album_list = []
country_list = []
genre_list = []
rank = []

for country in countries:
    top_list = []
    music_url = f"https://rss.itunes.apple.com/api/v1/{country}/apple-music/top-songs/all/5/explicit.json"
    
    try:
        response = requests.get(music_url).json()
        top_list.append(response["feed"]["results"])
        country_df = pd.DataFrame(top_list)
        for x in range (0,5):
            rank.append(x+1)
            song_list.append(country_df[x][0]['name'])
            country_list.append(country)
            artist_list.append(country_df[x][0]['artistName'])
            album_list.append(country_df[x][0]["collectionName"])
            genre_list.append(country_df[x][0]["genres"][0]["name"])
        
    except:
        print(f"Can't find {country}. Skipping... ")

# Create a dataframe with the country, song name and details, and the source        
apple_top_df = pd.DataFrame({
    "Country" : country_list,
    "Name" : song_list,
    "Artist" : artist_list,
    "Album" : album_list,
    "Genre" : genre_list,
    "Rank" : rank
})

#Clean the dataframe to match our pre-decided naming convention for the group
apple_top_df['Country'] = apple_top_df['Country'].replace({'hk': 'Hong Kong',
                           'nl': 'Netherlands',
                           'au': 'Australia',
                           'ca': 'Canada',
                           'fr': 'France',
                           'jp': 'Japan',
                           'gb': 'UK',
                           'de': 'Germany',
                           'us': 'US'
                          })
apple_top_df['Source'] = 'Apple'
apple_top_df.head()
# Out:
#      Country                 Name                           Artist  \
# 0  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1  Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2  Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3  Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4  Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
#
#                                                Album  Genre  Rank Source
# 0                                  Señorita - Single    流行樂     1  Apple
# 1  Frozen 2 (Original Motion Picture Soundtrack /...    原聲帶     2  Apple
# 2                                      說好不哭 - Single  國語流行樂     3  Apple
# 3  Frozen 2 (Original Motion Picture Soundtrack /...    原聲帶     4  Apple
# 4                       讓愛高飛 (劇集《多功能老婆》片尾曲) - Single    廣東歌     5  Apple

# %%
#cleaning the dataframe to be more readable 

translator = Translator()

apple_top_df['Genre'] = apple_top_df['Genre'].apply(translator.translate, dest='en').apply(getattr, args=('text',))
apple_top_df['Genre'] = apple_top_df['Genre'].replace({'pop music' : 'Pop', 
                                                                   'Mandarin pop music' : 'Pop',
                                                                   'Alternative Music' : 'Alternative',
                                                                   'R & B, soul' : 'R&B/Soul',
                                                                   'priest' : 'Priest'
                                                                })
apple_top_df.head()
# Out:
#      Country                 Name                           Artist  \
# 0  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1  Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2  Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3  Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4  Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
#
#                                                Album           Genre  Rank  \
# 0                                  Señorita - Single             Pop     1
# 1  Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                      說好不哭 - Single             Pop     3
# 3  Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                       讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
#
#   Source
# 0  Apple
# 1  Apple
# 2  Apple
# 3  Apple
# 4  Apple

# %% [markdown]
# # LastFM API to get the top tracks by region in radio

# %%
#start of lastFM data search

jsonFormat = '&format=json'

lastfm_url = 'http://ws.audioscrobbler.com/2.0/?method=chart.gettoptracks'
lastfm_url_end = '&api_key=' + lastfm_api_key + jsonFormat

# %%
# Get the top 5 tracks
limit = '5'

countries = ["Hong Kong", "Netherlands", "Australia", 
             "Canada", "France", "Japan", "united kingdom", "Germany", "united states"]
song_list = []
artist_list = []
country_list = []
rank = []

for country in countries:
    top_list = []
    urlgeo = lastfm_url+'&limit=' + limit + '&country=' + country + lastfm_url_end
    try:
        lastfm_response = requests.get(urlgeo).json()
        top_list.append(lastfm_response["tracks"]["track"])
        temp_df = pd.DataFrame(top_list)
        for x in range (0,5):
            rank.append(x+1)
            song_list.append(temp_df[x][0]['name'])
            country_list.append(country)
            artist_list.append(temp_df[x][0]['artist']['name'])
    except:
        print(f"Couldn't find {country}")

# %%
#Build the dataframe for LastFM Data
lastfm_top_df=pd.DataFrame({
    "Country" : country_list,
    "Artist" : artist_list,
    "Name" : song_list,
    "Rank" : rank
})

lastfm_top_df["Source"] = "LastFM"

lastfm_top_df.head()
# Out:
#      Country         Artist                             Name  Rank  Source
# 0  Hong Kong  Billie Eilish              Everything I Wanted     1  LastFM
# 1  Hong Kong  Billie Eilish                          bad guy     2  LastFM
# 2  Hong Kong     The Weeknd                        Heartless     3  LastFM
# 3  Hong Kong       Dua Lipa                  doN'T StArT nOw     4  LastFM
# 4  Hong Kong   Mariah Carey  All I Want for Christmas Is You     5  LastFM

# %%
# Get the album information for each track
# Need to use another API call to get Album information
albums = []
for index, row in lastfm_top_df.iterrows():
    try:
        track_url = 'http://ws.audioscrobbler.com/2.0/?method=track.getInfo&artist=' + row['Artist'] + '&track=' + row['Name'] + '&autocorrect=1' + lastfm_url_end
        lastfm_response = requests.get(track_url).json()
        albums.append(lastfm_response['track']['album']['title'])
    except:
        print(f"Couldn\'t find track information for {row['Name']}")
        albums.append(row['Name'])
# Out:
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw
# Couldn't find track information for doN'T StArT nOw

# %%
lastfm_top_df["Album"] = albums
lastfm_top_df.replace(to_replace="united kingdom", value="UK", inplace=True)
lastfm_top_df.replace(to_replace="united states", value="US", inplace=True)

# %% [markdown]
# # Switching to Apple Music's API to get Genre information for LastFM Tracks
#
# As mentioned earlier, Apple Music cleanly generates Genre information as compared to the other APIs.  We decided to standardize on Apple for continuity

# %%
genre_list = []

for song in lastfm_top_df["Name"]:
    artist = f"term={song}"
    media = 'media=music'
    entity = 'entity=song'
    limit = 'limit=1'

    url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit
    response = requests.get(url).json()

    genre_list.append(response["results"][-1]['primaryGenreName'])

lastfm_top_df["Genre"] = genre_list
lastfm_top_df = lastfm_top_df[['Country', 'Name', 'Artist', 'Album', 'Genre', 'Rank', 'Source']]

lastfm_top_df.head()
# Out:
#      Country                             Name         Artist  \
# 0  Hong Kong              Everything I Wanted  Billie Eilish
# 1  Hong Kong                          bad guy  Billie Eilish
# 2  Hong Kong                        Heartless     The Weeknd
# 3  Hong Kong                  doN'T StArT nOw       Dua Lipa
# 4  Hong Kong  All I Want for Christmas Is You   Mariah Carey
#
#                                    Album        Genre  Rank  Source
# 0                    everything i wanted  Alternative     1  LastFM
# 1  Now That's What I Call Music, Vol. 71  Alternative     2  LastFM
# 2                              Heartless      Country     3  LastFM
# 3                        doN'T StArT nOw          Pop     4  LastFM
# 4                        Merry Christmas      Holiday     5  LastFM

# %% [markdown]
# # Spotify API to obtain top tracks by geo

# %%
#start of spotify data search

spotify = spotipy.Spotify()
credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

# %%
spotify =spotipy.Spotify(auth=token)
playlist_name = []
p_id = []
owners_p=[]

playlists=spotify.search(q="Top 50",type = "playlist",limit=50)
for x,y in enumerate(playlists["playlists"]["items"]):
    play_name = (x,y["name"])
    playlist_id = y["uri"]
    owners = (y["owner"]["display_name"])
    #owner_final=owners[]
    if owners == "spotifycharts":
        playlist_name.append(play_name[1])
        p_id.append(playlist_id)
        owners_p.append(owners)

play_final = {
    "Playlist Name":playlist_name,
    "Playlist_ID":p_id,
    "Owners":owners_p
}
playlist_df = pd.DataFrame(play_final)
playlist_df.head()
# Out:
#     Playlist Name                              Playlist_ID         Owners
# 0   Global Top 50  spotify:playlist:37i9dQZEVXbMDoHDwVN2tF  spotifycharts
# 1   Brazil Top 50  spotify:playlist:37i9dQZEVXbMXbN3EUUhlg  spotifycharts
# 2    Spain Top 50  spotify:playlist:37i9dQZEVXbNFJfN1Vw8d9  spotifycharts
# 3  Germany Top 50  spotify:playlist:37i9dQZEVXbJiZcmkrIHGU  spotifycharts
# 4   Mexico Top 50  spotify:playlist:37i9dQZEVXbO3qyFxbkOE1  spotifycharts

# %% [markdown]
# ## We noticed that Hong Kong didn't show up in this list even though it follows the same naming convention.  So we added in code to pick up the appropriate playlist

# %%
playlist_name_t = []
p_id_t = []
owners_p_t=[]

playlists=spotify.search(q="Hong Kong Top 50",type = "playlist",limit=50)
for x,y in enumerate(playlists["playlists"]["items"]):
    play_name = (x,y["name"])
    playlist_id = y["uri"]
    owners = (y["owner"]["display_name"])
    #owner_final=owners[]
    if owners == "spotifycharts":
        playlist_name_t.append(play_name[1])
        p_id_t.append(playlist_id)
        owners_p_t.append(owners)

play_final_t = {
    "Playlist Name":playlist_name_t,
    "Playlist_ID":p_id_t,
    "Owners":owners_p_t
}
playlist_df_t = pd.DataFrame(play_final_t)

# %%
final_playists_df = pd.concat([playlist_df,playlist_df_t])
final_playists_df.reset_index(inplace=True, drop=True)
final_playists_df
# Out:
#             Playlist Name                              Playlist_ID  \
# 0           Global Top 50  spotify:playlist:37i9dQZEVXbMDoHDwVN2tF
# 1           Brazil Top 50  spotify:playlist:37i9dQZEVXbMXbN3EUUhlg
# 2            Spain Top 50  spotify:playlist:37i9dQZEVXbNFJfN1Vw8d9
# 3          Germany Top 50  spotify:playlist:37i9dQZEVXbJiZcmkrIHGU
# 4           Mexico Top 50  spotify:playlist:37i9dQZEVXbO3qyFxbkOE1
# 5      Netherlands Top 50  spotify:playlist:37i9dQZEVXbKCF6dqVpDkS
# 6        Argentina Top 50  spotify:playlist:37i9dQZEVXbMMy2roB9myp
# 7        Australia Top 50  spotify:playlist:37i9dQZEVXbJPcfkRz0wJ0
# 8            Italy Top 50  spotify:playlist:37i9dQZEVXbIQnj7RRhdSX
# 9            Japan Top 50  spotify:playlist:37i9dQZEVXbKXQ4mDTEBXq
# 10           Chile Top 50  spotify:playlist:37i9dQZEVXbL0GavIqMTeb
# 11          Sweden Top 50  spotify:playlist:37i9dQZEVXbLoATJ81JYXz
# 12       Indonesia Top 50  spotify:playlist:37i9dQZEVXbObFQZ3JLcXt
# 13          France Top 50  spotify:playlist:37i9dQZEVXbIPWwFssbupI
# 14     Philippines Top 50  spotify:playlist:37i9dQZEVXbNBz9cRCSFkY
# 15          Norway Top 50  spotify:playlist:37i9dQZEVXbJvfa0Yxg7E7
# 16           India Top 50  spotify:playlist:37i9dQZEVXbLZ52XmnySJg
# 17        Colombia Top 50  spotify:playlist:37i9dQZEVXbOa2lmxNORXQ
# 18          Turkey Top 50  spotify:playlist:37i9dQZEVXbIVYVBNw9D5K
# 19   United States Top 50  spotify:playlist:37i9dQZEVXbLRQDuF5jeBp
# 20            Peru Top 50  spotify:playlist:37i9dQZEVXbJfdy5b0KP7W
# 21  United Kingdom Top 50  spotify:playlist:37i9dQZEVXbLnolsZ8PSNw
# 22         Finland Top 50  spotify:playlist:37i9dQZEVXbMxcczTSoGwZ
# 23         Ireland Top 50  spotify:playlist:37i9dQZEVXbKM896FDX8L1
# 24         Denmark Top 50  spotify:playlist:37i9dQZEVXbL3J0k32lWnN
# 25        Paraguay Top 50  spotify:playlist:37i9dQZEVXbNOUPGj7tW6T
# 26          Canada Top 50  spotify:playlist:37i9dQZEVXbKj23U1GF4IR
# 27          Taiwan Top 50  spotify:playlist:37i9dQZEVXbMnZEatlMSiu
# 28          Poland Top 50  spotify:playlist:37i9dQZEVXbN6itCcaL3Tt
# 29         Belgium Top 50  spotify:playlist:37i9dQZEVXbJNSeeHswcKB
# 30        Thailand Top 50  spotify:playlist:37i9dQZEVXbMnz8KIWsvf9
# 31       Singapore Top 50  spotify:playlist:37i9dQZEVXbK4gjvS1FjPY
# 32        Malaysia Top 50  spotify:playlist:37i9dQZEVXbJlfUljuZExa
# 33         Ecuador Top 50  spotify:playlist:37i9dQZEVXbJlM6nvL1nD1
# 34        Portugal Top 50  spotify:playlist:37i9dQZEVXbKyJS56d1pgi
# 35          Panama Top 50  spotify:playlist:37i9dQZEVXbKypXHVwk1f0
# 36         Uruguay Top 50  spotify:playlist:37i9dQZEVXbMJJi3wgRbAy
# 37       Guatemala Top 50  spotify:playlist:37i9dQZEVXbLy5tBFyQvd4
# 38         Bolivia Top 50  spotify:playlist:37i9dQZEVXbJqfMFK4d691
# 39         Vietnam Top 50  spotify:playlist:37i9dQZEVXbLdGSmz6xilI
# 40         Hungary Top 50  spotify:playlist:37i9dQZEVXbNHwMxAkvmF8
# 41       Hong Kong Top 50  spotify:playlist:37i9dQZEVXbLwpL8TjsxOG
# 42     Hong Kong Viral 50  spotify:playlist:37i9dQZEVXbKXd6qahcpCg
#
#            Owners
# 0   spotifycharts
# 1   spotifycharts
# 2   spotifycharts
# 3   spotifycharts
# 4   spotifycharts
# 5   spotifycharts
# 6   spotifycharts
# 7   spotifycharts
# 8   spotifycharts
# 9   spotifycharts
# 10  spotifycharts
# 11  spotifycharts
# 12  spotifycharts
# 13  spotifycharts
# 14  spotifycharts
# 15  spotifycharts
# 16  spotifycharts
# 17  spotifycharts
# 18  spotifycharts
# 19  spotifycharts
# 20  spotifycharts
# 21  spotifycharts
# 22  spotifycharts
# 23  spotifycharts
# 24  spotifycharts
# 25  spotifycharts
# 26  spotifycharts
# 27  spotifycharts
# 28  spotifycharts
# 29  spotifycharts
# 30  spotifycharts
# 31  spotifycharts
# 32  spotifycharts
# 33  spotifycharts
# 34  spotifycharts
# 35  spotifycharts
# 36  spotifycharts
# 37  spotifycharts
# 38  spotifycharts
# 39  spotifycharts
# 40  spotifycharts
# 41  spotifycharts
# 42  spotifycharts

# %%
tracks = []
p_id2=[]
test = []
p_name = []
t_ids = []
tracker=[]
p_list=final_playists_df["Playlist_ID"]
data=p_list.str.split(":")
for x in data:
    id =(x[2])
    p_id2.append(id)

for x in p_id2:
    response_json=spotify.user_playlist_tracks("spotifycharts", x)
    rank=1
    cur_play = final_playists_df.loc[final_playists_df["Playlist_ID"] == f"spotify:playlist:{x}"]["Playlist Name"].unique()[0]
    counter = 0
    for i,t in enumerate (response_json["items"]):
        name=(t["track"]["name"])
        t_id=(t["track"]["id"])
        tracks.append(name)
        t_ids.append(t_id)
        test.append(x)
        p_name.append(cur_play)
        rank = rank + 1
        tracker.append(counter+1)
        counter+=1
        if (rank == 6):
            break

music_df = pd.DataFrame({
    "Playlist Name" : p_name,
    "Playlist ID" : test,
    "Name" : tracks,
    "ID":t_ids,
    "Rank":tracker
})
music_df["Playlist Name"] = music_df["Playlist Name"].replace({'United States Top 50' : 'US Top 50', 'United Kingdom Top 50' : 'UK Top 50', 'Hong Kong Viral 50': 'HK Viral 50'})
music_df
# Out:
#      Playlist Name             Playlist ID               Name  \
# 0    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Dance Monkey
# 1    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Lucid Dreams
# 2    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            ROXANNE
# 3    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            Circles
# 4    Global Top 50  37i9dQZEVXbMDoHDwVN2tF           Memories
# ..             ...                     ...                ...
# 210    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Lost in the Woods
# 211    HK Viral 50  37i9dQZEVXbKXd6qahcpCg            Falling
# 212    HK Viral 50  37i9dQZEVXbKXd6qahcpCg   Into the Unknown
# 213    HK Viral 50  37i9dQZEVXbKXd6qahcpCg       All Is Found
# 214    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Bauhinia Rhapsody
#
#                          ID  Rank
# 0    1rgnBhdG2JDFTbYkYRZAku     1
# 1    285pBltuF7vW8TeWk8hdRR     2
# 2    696DnlkuDOXcMAnKlTgXXK     3
# 3    21jGcNKet2qwijlDFuPiPb     4
# 4    2b8fOow8UzyDFAE27YhOZM     5
# ..                      ...   ...
# 210  7namdlOhbtsc8FvoSafOQt     1
# 211  4TnjEaWOeW0eKTKIEvJyCa     2
# 212  3Z0oQ8r78OUaHvGPiDBR3W     3
# 213  61HVbcNeRACZpyvHrc3AnD     4
# 214  6gTAS57L0jTyk4OrenilJS     5
#
# [215 rows x 5 columns]

# %%
country = []
Range=music_df["Playlist Name"].str.split(" ")[:,]

for x in Range:
    n_c=(x[0])
    country.append(n_c)
music_df["Country"]=country
music_df
music_df.to_csv("music.csv")

music_df
# Out:
#      Playlist Name             Playlist ID               Name  \
# 0    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Dance Monkey
# 1    Global Top 50  37i9dQZEVXbMDoHDwVN2tF       Lucid Dreams
# 2    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            ROXANNE
# 3    Global Top 50  37i9dQZEVXbMDoHDwVN2tF            Circles
# 4    Global Top 50  37i9dQZEVXbMDoHDwVN2tF           Memories
# ..             ...                     ...                ...
# 210    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Lost in the Woods
# 211    HK Viral 50  37i9dQZEVXbKXd6qahcpCg            Falling
# 212    HK Viral 50  37i9dQZEVXbKXd6qahcpCg   Into the Unknown
# 213    HK Viral 50  37i9dQZEVXbKXd6qahcpCg       All Is Found
# 214    HK Viral 50  37i9dQZEVXbKXd6qahcpCg  Bauhinia Rhapsody
#
#                          ID  Rank Country
# 0    1rgnBhdG2JDFTbYkYRZAku     1  Global
# 1    285pBltuF7vW8TeWk8hdRR     2  Global
# 2    696DnlkuDOXcMAnKlTgXXK     3  Global
# 3    21jGcNKet2qwijlDFuPiPb     4  Global
# 4    2b8fOow8UzyDFAE27YhOZM     5  Global
# ..                      ...   ...     ...
# 210  7namdlOhbtsc8FvoSafOQt     1      HK
# 211  4TnjEaWOeW0eKTKIEvJyCa     2      HK
# 212  3Z0oQ8r78OUaHvGPiDBR3W     3      HK
# 213  61HVbcNeRACZpyvHrc3AnD     4      HK
# 214  6gTAS57L0jTyk4OrenilJS     5      HK
#
# [215 rows x 6 columns]

# %%
m_country=["Hong","Netherlands","Russia","Australia","Canada","France","Japan","Germany","US", "UK"]
final_music_1=music_df.loc[music_df["Country"].isin(m_country)]
spotify_top_df =final_music_1.reset_index()

spotify_top_df
# Out:
#     index       Playlist Name             Playlist ID  \
# 0      15      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 1      16      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 2      17      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 3      18      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 4      19      Germany Top 50  37i9dQZEVXbJiZcmkrIHGU
# 5      25  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 6      26  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 7      27  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 8      28  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 9      29  Netherlands Top 50  37i9dQZEVXbKCF6dqVpDkS
# 10     35    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 11     36    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 12     37    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 13     38    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 14     39    Australia Top 50  37i9dQZEVXbJPcfkRz0wJ0
# 15     45        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 16     46        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 17     47        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 18     48        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 19     49        Japan Top 50  37i9dQZEVXbKXQ4mDTEBXq
# 20     65       France Top 50  37i9dQZEVXbIPWwFssbupI
# 21     66       France Top 50  37i9dQZEVXbIPWwFssbupI
# 22     67       France Top 50  37i9dQZEVXbIPWwFssbupI
# 23     68       France Top 50  37i9dQZEVXbIPWwFssbupI
# 24     69       France Top 50  37i9dQZEVXbIPWwFssbupI
# 25     95           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 26     96           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 27     97           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 28     98           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 29     99           US Top 50  37i9dQZEVXbLRQDuF5jeBp
# 30    105           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 31    106           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 32    107           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 33    108           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 34    109           UK Top 50  37i9dQZEVXbLnolsZ8PSNw
# 35    130       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 36    131       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 37    132       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 38    133       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 39    134       Canada Top 50  37i9dQZEVXbKj23U1GF4IR
# 40    205    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 41    206    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 42    207    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 43    208    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
# 44    209    Hong Kong Top 50  37i9dQZEVXbLwpL8TjsxOG
#
#                                         Name                      ID  Rank  \
# 0                                KEIN SCHLAF  6416zJN0FGPmh1Ph4BH2h3     1
# 1                                       COLT  76IVpz47q3ghkxoUeTTEKb     2
# 2                                     Roller  6hw1Sy9wZ8UCxYGdpKrU6M     3
# 3              Der Bratan bleibt der gleiche  2M39v73rNJmAXUXIW0oagP     4
# 4                               Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     5
# 5                               Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     1
# 6                                    ROXANNE  696DnlkuDOXcMAnKlTgXXK     2
# 7                               Pa Olvidarte  1RO8Q3w2Jkir8cvvGEApI0     3
# 8                               Lucid Dreams  285pBltuF7vW8TeWk8hdRR     4
# 9                                   Memories  2b8fOow8UzyDFAE27YhOZM     5
# 10                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     1
# 11                                   ROXANNE  696DnlkuDOXcMAnKlTgXXK     2
# 12                                   Circles  21jGcNKet2qwijlDFuPiPb     3
# 13                           Don't Start Now  6WrI0LAC5M1Rw2MnX2ZvEg     4
# 14                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     5
# 15                                 Pretender  58dxGXavrcagRqA58fNB0Z     1
# 16                                 Hakujitsu  0mNO3xUzjsI17GXO1DRFCH     2
# 17                                        宿命  2yozZfRYHP7Elsymghu5t3     3
# 18                                    イエスタデイ  3S3DDZrPOYTirleXRyHnNM     4
# 19                                     ノーダウト  5DMEvbg3gUmiR5HIBWdveV     5
# 20                            Ne reviens pas  4TnFANpjVwVKWzkxNzIyFH     1
# 21                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     2
# 22                                   Popopop  18HNGxDOcshRU2Hdu8tMOM     3
# 23                      Mayday (feat. Ninho)  1SVuEeerYIwjCRsF5MGzX3     4
# 24                                    Jamais  2MCAs3ttHSuDm1RHL0rqTF     5
# 25                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     1
# 26  Bandit (with YoungBoy Never Broke Again)  6Gg1gjgKi2AK4e0qzsR7sd     2
# 27                                   ROXANNE  696DnlkuDOXcMAnKlTgXXK     3
# 28                                   Circles  21jGcNKet2qwijlDFuPiPb     4
# 29                                   Robbery  6Hj9jySrnFppAI0sEMCZpJ     5
# 30                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     1
# 31           All I Want for Christmas Is You  0bYg9bo50gSsH3LtXe2SQn     2
# 32                            Last Christmas  2FRnf9qhLbvw8fu4IBXx78     3
# 33     Own It (feat. Ed Sheeran & Burna Boy)  07s9NNOT0sZQp7TyolLLgu     4
# 34                             Before You Go  2gMXnyrvIjhVBUZwvLZDMP     5
# 35                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     1
# 36                                   ROXANNE  696DnlkuDOXcMAnKlTgXXK     2
# 37                              Lucid Dreams  285pBltuF7vW8TeWk8hdRR     3
# 38  Bandit (with YoungBoy Never Broke Again)  6Gg1gjgKi2AK4e0qzsR7sd     4
# 39                                   Circles  21jGcNKet2qwijlDFuPiPb     5
# 40                                  Señorita  6v3KW9xbzN5yKLt9YKDYA2     1
# 41                                  Memories  2b8fOow8UzyDFAE27YhOZM     2
# 42                                   Circles  21jGcNKet2qwijlDFuPiPb     3
# 43                       everything i wanted  3ZCTVFBt2Brf31RLEnCkWJ     4
# 44                              Dance Monkey  1rgnBhdG2JDFTbYkYRZAku     5
#
#         Country
# 0       Germany
# 1       Germany
# 2       Germany
# 3       Germany
# 4       Germany
# 5   Netherlands
# 6   Netherlands
# 7   Netherlands
# 8   Netherlands
# 9   Netherlands
# 10    Australia
# 11    Australia
# 12    Australia
# 13    Australia
# 14    Australia
# 15        Japan
# 16        Japan
# 17        Japan
# 18        Japan
# 19        Japan
# 20       France
# 21       France
# 22       France
# 23       France
# 24       France
# 25           US
# 26           US
# 27           US
# 28           US
# 29           US
# 30           UK
# 31           UK
# 32           UK
# 33           UK
# 34           UK
# 35       Canada
# 36       Canada
# 37       Canada
# 38       Canada
# 39       Canada
# 40         Hong
# 41         Hong
# 42         Hong
# 43         Hong
# 44         Hong

# %% [markdown]
# ## Similar to above, we are leveraging Apple Music's API to get the Genre information

# %%
spot_album_list = []
spot_genre_list = []
spot_artist_list = []

for song in spotify_top_df["Name"]:
    artist = f"term={song}"
    media = 'media=music'
    entity = 'entity=song'
    limit = 'limit=1'

    url = 'http://itunes.apple.com/search?' + artist + "&" + media + "&" + entity + "&" + limit
    response = requests.get(url).json()

    try:
        spot_genre_list.append(response["results"][0]['primaryGenreName'])
        spot_album_list.append(response["results"][0]["collectionName"])
        spot_artist_list.append(response["results"][0]['artistName'])
    except:
        print(f"Couldn\'t find {song}")
        spot_genre_list.append("NA")
        spot_album_list.append("NA")
        spot_artist_list.append("NA")
# Out:
# Couldn't find Bandit (with YoungBoy Never Broke Again)
# Couldn't find Own It (feat. Ed Sheeran & Burna Boy)
# Couldn't find Bandit (with YoungBoy Never Broke Again)

# %%
spotify_top_df["Genre"] = spot_genre_list
spotify_top_df["Album"] = spot_album_list
spotify_top_df["Artist"] = spot_artist_list
spotify_top_df["Source"] = 'Spotify'
# spotify_top_df['Rank'] = np.arange(len(spotify_top_df))
# spotify_top_df['Rank'] = spotify_top5['Rank'] % 5 + 1

spotify_top_df = spotify_top_df[['Country', 'Name', 'Artist', 'Album', 'Genre', 'Rank', 'Source']]
spotify_top_df['Country'] = spotify_top_df['Country'].replace({'Hong' : 'Hong Kong'}) 


spotify_top_df
# Out:
#         Country                                      Name  \
# 0       Germany                               KEIN SCHLAF
# 1       Germany                                      COLT
# 2       Germany                                    Roller
# 3       Germany             Der Bratan bleibt der gleiche
# 4       Germany                              Dance Monkey
# 5   Netherlands                              Dance Monkey
# 6   Netherlands                                   ROXANNE
# 7   Netherlands                              Pa Olvidarte
# 8   Netherlands                              Lucid Dreams
# 9   Netherlands                                  Memories
# 10    Australia                              Dance Monkey
# 11    Australia                                   ROXANNE
# 12    Australia                                   Circles
# 13    Australia                           Don't Start Now
# 14    Australia                              Lucid Dreams
# 15        Japan                                 Pretender
# 16        Japan                                 Hakujitsu
# 17        Japan                                        宿命
# 18        Japan                                    イエスタデイ
# 19        Japan                                     ノーダウト
# 20       France                            Ne reviens pas
# 21       France                              Dance Monkey
# 22       France                                   Popopop
# 23       France                      Mayday (feat. Ninho)
# 24       France                                    Jamais
# 25           US                              Lucid Dreams
# 26           US  Bandit (with YoungBoy Never Broke Again)
# 27           US                                   ROXANNE
# 28           US                                   Circles
# 29           US                                   Robbery
# 30           UK                              Dance Monkey
# 31           UK           All I Want for Christmas Is You
# 32           UK                            Last Christmas
# 33           UK     Own It (feat. Ed Sheeran & Burna Boy)
# 34           UK                             Before You Go
# 35       Canada                              Dance Monkey
# 36       Canada                                   ROXANNE
# 37       Canada                              Lucid Dreams
# 38       Canada  Bandit (with YoungBoy Never Broke Again)
# 39       Canada                                   Circles
# 40    Hong Kong                                  Señorita
# 41    Hong Kong                                  Memories
# 42    Hong Kong                                   Circles
# 43    Hong Kong                       everything i wanted
# 44    Hong Kong                              Dance Monkey
#
#                                    Artist  \
# 0                                     LGM
# 1                                 Afroman
# 2                              April Wine
# 3                             Capital Bra
# 4                             Tones and I
# 5                             Tones and I
# 6                          Arizona Zervas
# 7   ChocQuibTown, Zion & Lennox & Farruko
# 8                              Juice WRLD
# 9                                Maroon 5
# 10                            Tones and I
# 11                         Arizona Zervas
# 12                            Post Malone
# 13                               Dua Lipa
# 14                             Juice WRLD
# 15                             Steve Aoki
# 16                               King Gnu
# 17                     Yasuharu Takanashi
# 18                            The Beatles
# 19                               No Doubt
# 20                         Salomé Leclerc
# 21                            Tones and I
# 22                           musiqman Jr.
# 23                                    SCH
# 24                   Charlotte Gainsbourg
# 25                             Juice WRLD
# 26                                     NA
# 27                         Arizona Zervas
# 28                            Post Malone
# 29                             Juice WRLD
# 30                            Tones and I
# 31                           Mariah Carey
# 32                                  Wham!
# 33                                     NA
# 34                          Lewis Capaldi
# 35                            Tones and I
# 36                         Arizona Zervas
# 37                             Juice WRLD
# 38                                     NA
# 39                            Post Malone
# 40          Shawn Mendes & Camila Cabello
# 41                               Maroon 5
# 42                            Post Malone
# 43                          Billie Eilish
# 44                            Tones and I
#
#                                                 Album          Genre  Rank  \
# 0                                Kein Schlaf - Single    Hip-Hop/Rap     1
# 1                                      The Good Times    Hip-Hop/Rap     2
# 2            Classic Masters: April Wine (Remastered)           Rock     3
# 3              Der Bratan bleibt der gleiche - Single    Hip-Hop/Rap     4
# 4                            The Kids Are Coming - EP    Alternative     5
# 5                            The Kids Are Coming - EP    Alternative     1
# 6                                    ROXANNE - Single    Hip-Hop/Rap     2
# 7   Pa Olvidarte (Remix) [feat. Manuel Turizo] - S...  Urbano latino     3
# 8                             Goodbye & Good Riddance    Hip-Hop/Rap     4
# 9                                   Memories - Single            Pop     5
# 10                           The Kids Are Coming - EP    Alternative     1
# 11                                   ROXANNE - Single    Hip-Hop/Rap     2
# 12                               Hollywood's Bleeding    Hip-Hop/Rap     3
# 13                           Don't Start Now - Single            Pop     4
# 14                            Goodbye & Good Riddance    Hip-Hop/Rap     5
# 15        Pretender (feat. Lil Yachty & AJR) - Single          Dance     1
# 16                                 Hakujitsu - Single          J-Pop     2
# 17             "Fairy Tail" Original Soundtrack Vol.1          Anime     3
# 18                                   1 (2015 Version)           Rock     4
# 19                              The Singles 1992-2003            Pop     5
# 20                                    Sous les arbres     French Pop     1
# 21                           The Kids Are Coming - EP    Alternative     2
# 22                                       Musiqruisin'       R&B/Soul     3
# 23                                            Rooftop    Hip-Hop/Rap     4
# 24                                               5:55    Alternative     5
# 25                            Goodbye & Good Riddance    Hip-Hop/Rap     1
# 26                                                 NA             NA     2
# 27                                   ROXANNE - Single    Hip-Hop/Rap     3
# 28                               Hollywood's Bleeding    Hip-Hop/Rap     4
# 29                                Death Race for Love    Hip-Hop/Rap     5
# 30                           The Kids Are Coming - EP    Alternative     1
# 31                                    Merry Christmas        Holiday     2
# 32                            Last Christmas - Single        Holiday     3
# 33                                                 NA             NA     4
# 34  Divinely Uninspired To a Hellish Extent (Exten...    Alternative     5
# 35                           The Kids Are Coming - EP    Alternative     1
# 36                                   ROXANNE - Single    Hip-Hop/Rap     2
# 37                            Goodbye & Good Riddance    Hip-Hop/Rap     3
# 38                                                 NA             NA     4
# 39                               Hollywood's Bleeding    Hip-Hop/Rap     5
# 40                                  Señorita - Single            Pop     1
# 41                                  Memories - Single            Pop     2
# 42                               Hollywood's Bleeding    Hip-Hop/Rap     3
# 43                       everything i wanted - Single    Alternative     4
# 44                           The Kids Are Coming - EP    Alternative     5
#
#      Source
# 0   Spotify
# 1   Spotify
# 2   Spotify
# 3   Spotify
# 4   Spotify
# 5   Spotify
# 6   Spotify
# 7   Spotify
# 8   Spotify
# 9   Spotify
# 10  Spotify
# 11  Spotify
# 12  Spotify
# 13  Spotify
# 14  Spotify
# 15  Spotify
# 16  Spotify
# 17  Spotify
# 18  Spotify
# 19  Spotify
# 20  Spotify
# 21  Spotify
# 22  Spotify
# 23  Spotify
# 24  Spotify
# 25  Spotify
# 26  Spotify
# 27  Spotify
# 28  Spotify
# 29  Spotify
# 30  Spotify
# 31  Spotify
# 32  Spotify
# 33  Spotify
# 34  Spotify
# 35  Spotify
# 36  Spotify
# 37  Spotify
# 38  Spotify
# 39  Spotify
# 40  Spotify
# 41  Spotify
# 42  Spotify
# 43  Spotify
# 44  Spotify

# %% [markdown]
# # Now that we have the data from each of the APIs, we will create a consolidated DataFrame to run our audio features analysis

# %%
music = [apple_top_df, lastfm_top_df, spotify_top_df]

merge_df = pd.concat(music)

merge_df
# Out:
#       Country                 Name                           Artist  \
# 0   Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1   Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2   Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3   Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4   Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
# ..        ...                  ...                              ...
# 40  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 41  Hong Kong             Memories                         Maroon 5
# 42  Hong Kong              Circles                      Post Malone
# 43  Hong Kong  everything i wanted                    Billie Eilish
# 44  Hong Kong         Dance Monkey                      Tones and I
#
#                                                 Album           Genre  Rank  \
# 0                                   Señorita - Single             Pop     1
# 1   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                       說好不哭 - Single             Pop     3
# 3   Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                        讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
# ..                                                ...             ...   ...
# 40                                  Señorita - Single             Pop     1
# 41                                  Memories - Single             Pop     2
# 42                               Hollywood's Bleeding     Hip-Hop/Rap     3
# 43                       everything i wanted - Single     Alternative     4
# 44                           The Kids Are Coming - EP     Alternative     5
#
#      Source
# 0     Apple
# 1     Apple
# 2     Apple
# 3     Apple
# 4     Apple
# ..      ...
# 40  Spotify
# 41  Spotify
# 42  Spotify
# 43  Spotify
# 44  Spotify
#
# [135 rows x 7 columns]

# %% [markdown]
# ## Obtain the Spotify ID for each of the tracks to get the audio features
#
# ## The API expects a Spotify ID, not a track name, so we must do this to get the information we need for analysis

# %%
spotify_id = []
for index, row in merge_df.iterrows():
    try:
        res = spotify.search(row["Name"], type="track", limit=1)
        spotify_id.append(res["tracks"]["items"][0]["id"])
    except:
        text = row["Name"]
        head, sep, tail = text.partition('(')
        res = spotify.search(head, type="track", limit=1)
        spotify_id.append(res["tracks"]["items"][0]["id"])
        continue
        
merge_df["Spotify ID"] = spotify_id
merge_df.head()
# Out:
#      Country                 Name                           Artist  \
# 0  Hong Kong             Señorita    Shawn Mendes & Camila Cabello
# 1  Hong Kong     Into the Unknown            Idina Menzel & AURORA
# 2  Hong Kong                 說好不哭                         周杰倫 & 阿信
# 3  Hong Kong        Show Yourself  Idina Menzel & Evan Rachel Wood
# 4  Hong Kong  讓愛高飛 (劇集《多功能老婆》片尾曲)                              周柏豪
#
#                                                Album           Genre  Rank  \
# 0                                  Señorita - Single             Pop     1
# 1  Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     2
# 2                                      說好不哭 - Single             Pop     3
# 3  Frozen 2 (Original Motion Picture Soundtrack /...      Soundtrack     4
# 4                       讓愛高飛 (劇集《多功能老婆》片尾曲) - Single  Guangdong song     5
#
#   Source              Spotify ID
# 0  Apple  0TK2YIli7K1leLovkQiNik
# 1  Apple  3Z0oQ8r78OUaHvGPiDBR3W
# 2  Apple  56wVfJKtnwlSZtC4NVgIrf
# 3  Apple  50WeOnXhM1H7AZEeIDoWfZ
# 4  Apple  7nIxo0dE9d4FBwPYhmdQae

# %% [markdown]
# ## Now that we have the Spotify ID, we can grab the audio features for each track

# %%
danceability = []
energy = []
key = []
loudness = []
speechiness = []
acousticness = []
instrumentalness = []
liveness = []
valence = []
tempo = []
duration_ms = []

for index, row in merge_df.iterrows():
    try:
        track_features = spotify.audio_features(tracks=row['Spotify ID'])
        danceability.append(track_features[0]["danceability"])
        energy.append(track_features[0]["energy"])
        key.append(track_features[0]["key"])
        loudness.append(track_features[0]["loudness"])
        speechiness.append(track_features[0]["speechiness"])
        acousticness.append(track_features[0]["acousticness"])
        instrumentalness.append(track_features[0]["instrumentalness"])
        liveness.append(track_features[0]["liveness"])
        valence.append(track_features[0]["valence"])
        tempo.append(track_features[0]["tempo"])
        duration_ms.append(track_features[0]["duration_ms"])
    except:
        print(f"Couldn't find details for {row['Spotify ID']}")
        continue

# %%
merge_df["danceability"] = danceability
merge_df["energy"] = energy
merge_df["key"] = key
merge_df["loudness"] = loudness
merge_df["speechiness"] = speechiness
merge_df["acousticness"] = acousticness
merge_df["instrumentalness"] = instrumentalness
merge_df["liveness"] = liveness
merge_df["valence"] = valence
merge_df["tempo"] = tempo
merge_df["duration_ms"] = duration_ms

# %%
merge_df.sort_values(by = ['Country', 'Source', 'Rank'], inplace=True)
merge_df.reset_index(drop=True, inplace=True)
output_file = merge_df.to_csv('track_analysis.csv')
merge_df.head(15)
# Out:
#       Country                             Name          Artist  \
# 0   Australia                     Dance Monkey     Tones and I
# 1   Australia                  Don't Start Now        Dua Lipa
# 2   Australia                     Lucid Dreams      Juice WRLD
# 3   Australia                          Ride It          Regard
# 4   Australia              Never Seen the Rain     Tones and I
# 5   Australia              Everything I Wanted   Billie Eilish
# 6   Australia                          bad guy   Billie Eilish
# 7   Australia                        Heartless      The Weeknd
# 8   Australia                  doN'T StArT nOw        Dua Lipa
# 9   Australia  All I Want for Christmas Is You    Mariah Carey
# 10  Australia                     Dance Monkey     Tones and I
# 11  Australia                          ROXANNE  Arizona Zervas
# 12  Australia                          Circles     Post Malone
# 13  Australia                  Don't Start Now        Dua Lipa
# 14  Australia                     Lucid Dreams      Juice WRLD
#
#                                     Album        Genre  Rank   Source  \
# 0                   Dance Monkey - Single          Pop     1    Apple
# 1                Don't Start Now - Single          Pop     2    Apple
# 2                 Goodbye & Good Riddance  Hip-Hop/Rap     3    Apple
# 3                        Ride It - Single        Dance     4    Apple
# 4                The Kids Are Coming - EP  Alternative     5    Apple
# 5                     everything i wanted  Alternative     1   LastFM
# 6   Now That's What I Call Music, Vol. 71  Alternative     2   LastFM
# 7                               Heartless      Country     3   LastFM
# 8                         doN'T StArT nOw          Pop     4   LastFM
# 9                         Merry Christmas      Holiday     5   LastFM
# 10               The Kids Are Coming - EP  Alternative     1  Spotify
# 11                       ROXANNE - Single  Hip-Hop/Rap     2  Spotify
# 12                   Hollywood's Bleeding  Hip-Hop/Rap     3  Spotify
# 13               Don't Start Now - Single          Pop     4  Spotify
# 14                Goodbye & Good Riddance  Hip-Hop/Rap     5  Spotify
#
#                 Spotify ID  danceability  energy  key  loudness  speechiness  \
# 0   2XU0oxnq2qxCpomAAuJY8K         0.824   0.588    6    -6.400       0.0924
# 1   6WrI0LAC5M1Rw2MnX2ZvEg         0.794   0.793   11    -4.521       0.0842
# 2   285pBltuF7vW8TeWk8hdRR         0.511   0.566    6    -7.230       0.2000
# 3   2tnVG71enUj33Ic2nFN6kZ         0.882   0.780    0    -4.256       0.0939
# 4   0JQ5MbyriK6ruD3t6RZ7ix         0.672   0.464    6    -5.624       0.0370
# 5   3ZCTVFBt2Brf31RLEnCkWJ         0.704   0.225    6   -14.454       0.0994
# 6   2Fxmhks0bxGSBdJ92vM42m         0.701   0.425    7   -10.965       0.3750
# 7   57vxBYXtHMk6H1aD29V7PU         0.531   0.750   10    -5.831       0.1110
# 8   6WrI0LAC5M1Rw2MnX2ZvEg         0.794   0.793   11    -4.521       0.0842
# 9   0bYg9bo50gSsH3LtXe2SQn         0.335   0.625    7    -7.462       0.0386
# 10  2XU0oxnq2qxCpomAAuJY8K         0.824   0.588    6    -6.400       0.0924
# 11  696DnlkuDOXcMAnKlTgXXK         0.621   0.601    6    -5.616       0.1480
# 12  21jGcNKet2qwijlDFuPiPb         0.695   0.762    0    -3.497       0.0395
# 13  6WrI0LAC5M1Rw2MnX2ZvEg         0.794   0.793   11    -4.521       0.0842
# 14  285pBltuF7vW8TeWk8hdRR         0.511   0.566    6    -7.230       0.2000
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 0        0.69200          0.000104    0.1490    0.513   98.027       209438
# 1        0.01250          0.000000    0.0952    0.677  123.941       183290
# 2        0.34900          0.000000    0.3400    0.218   83.903       239836
# 3        0.15900          0.000052    0.0973    0.867  117.945       157606
# 4        0.43000          0.000000    0.2840    0.271   92.069       200742
# 5        0.90200          0.657000    0.1060    0.243  120.006       245426
# 6        0.32800          0.130000    0.1000    0.562  135.128       194088
# 7        0.00632          0.000076    0.1170    0.198  169.954       200080
# 8        0.01250          0.000000    0.0952    0.677  123.941       183290
# 9        0.16400          0.000000    0.0708    0.346  150.277       241107
# 10       0.69200          0.000104    0.1490    0.513   98.027       209438
# 11       0.05220          0.000000    0.4600    0.457  116.735       163636
# 12       0.19200          0.002440    0.0863    0.553  120.042       215280
# 13       0.01250          0.000000    0.0952    0.677  123.941       183290
# 14       0.34900          0.000000    0.3400    0.218   83.903       239836

# %%
artist = merge_df.groupby(['Artist']).apply(lambda x: x.count())

# Draw plot
fig, ax = plt.subplots(figsize=(12,8), dpi= 80)
ax.vlines(x=artist.index, ymin=0, ymax=artist.Artist, color='c', alpha=0.7, linewidth=2)
ax.scatter(x=artist.index, y=artist.Artist, s=75, color='c', alpha=0.7)

# Title, Label, Ticks and Ylim
ax.set_title('Frequency of Artist Occurrences', fontdict={'size':22})
ax.set_ylabel('Frequency')
ax.set_xticks(artist.index)
ax.set_xticklabels(artist.index, rotation=60, fontdict={'horizontalalignment': 'right', 'size':12})
ax.set_ylim(0, 25)

for row in artist.itertuples():
    ax.text(row.Index, row.Artist+.5, s=round(row.Artist, 2), horizontalalignment= 'center', verticalalignment='bottom', fontsize=8)

plt.show()

# %%
songs = merge_df.groupby(['Name']).apply(lambda x: x.count())

# Draw plot
fig, ax = plt.subplots(figsize=(12,8), dpi= 80)
ax.vlines(x=songs.index, ymin=0, ymax=songs.Name, color='m', alpha=0.7, linewidth=2)
ax.scatter(x=songs.index, y=songs.Name, s=75, color='m', alpha=0.7)

# Title, Label, Ticks and Ylim
ax.set_title('Frequency of Track Occurrences', fontdict={'size':22})
ax.set_ylabel('Frequency')
ax.set_xticks(songs.index)
ax.set_xticklabels(songs.index, rotation=60, fontdict={'horizontalalignment': 'right', 'size':12})
ax.set_ylim(0, 15)

for row in songs.itertuples():
    ax.text(row.Index, row.Name+.5, s=round(row.Name, 2), horizontalalignment= 'center', verticalalignment='bottom', fontsize=8)

plt.show()

# %%
genre = merge_df.groupby(['Genre']).apply(lambda x: x.count())

# Draw plot
fig, ax = plt.subplots(figsize=(12,8), dpi= 80)
ax.vlines(x=genre.index, ymin=0, ymax=genre.Genre, color='g', alpha=0.7, linewidth=2)
ax.scatter(x=genre.index, y=genre.Genre, s=75, color='g', alpha=0.7)

# Title, Label, Ticks and Ylim
ax.set_title('Frequency of Genre Occurrences', fontdict={'size':22})
ax.set_ylabel('Frequency')
ax.set_xticks(genre.index)
ax.set_xticklabels(genre.index, rotation=60, fontdict={'horizontalalignment': 'right', 'size':12})
ax.set_ylim(0, 45)

for row in songs.itertuples():
    ax.text(row.Index, row.Genre+.5, s=round(row.Genre, 2), horizontalalignment= 'center', verticalalignment='bottom', fontsize=8)

plt.show()
